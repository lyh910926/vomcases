# %% [markdown]
# # Weatherdata

# %%
import warnings
warnings.filterwarnings("ignore")
import logging
logging.getLogger().setLevel(logging.CRITICAL)

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta, date

# %% [markdown]
# ## Timeseries

# %% [markdown]
# ### Precipitation

# %%
data_adelaide = np.genfromtxt("../../data/VOM_input/AdelaideRiver/dailyweather.prn",names=True  )
data_daly = np.genfromtxt("../../data/VOM_input/DalyUncleared/dailyweather.prn",names=True  )
data_dry = np.genfromtxt("../../data/VOM_input/DryRiver/dailyweather.prn",names=True  )
data_howard = np.genfromtxt("../../data/VOM_input/HowardSprings/dailyweather.prn",names=True  )
data_sturt = np.genfromtxt("../../data/VOM_input/SturtPlains/dailyweather.prn",names=True  )
data_litchfield = np.genfromtxt("../../data/VOM_input/Litchfield/dailyweather.prn",names=True  )

# %%
time = pd.date_range(str(int(data_adelaide["Day"][0])) + "-" +str(int(data_adelaide["Month"][0])) + "-" + str(int(data_adelaide["Year"][0])), periods=len(data_adelaide["Dcum"]), freq='D')   
time_lf = pd.date_range(str(int(data_litchfield["Day"][0])) + "-" +str(int(data_litchfield["Month"][0])) + "-" + str(int(data_litchfield["Year"][0])), periods=len(data_litchfield["Dcum"]), freq='D')

# %%
howard_pd = pd.DataFrame(data_howard, index=time)
adelaide_pd = pd.DataFrame(data_adelaide, index=time)
litch_pd = pd.DataFrame(data_litchfield, index=time_lf)
daly_pd = pd.DataFrame(data_daly, index=time)
dry_pd = pd.DataFrame(data_dry, index=time)
sturt_pd = pd.DataFrame(data_sturt, index=time)

# %%
fig, ax   = plt.subplots(nrows=5, ncols=1, figsize=(18, 20), sharex=True, sharey=True)   
ax[0].plot(howard_pd["Rain"])
ax[0].set_ylabel("Precipitation (mm d$^{-}$$^{1}$)", size=20)
ax[0].text(0.01, 0.9, "a)", ha='left', va='center', transform=ax[0].transAxes, fontsize=20)
for tick in ax[0].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[1].plot(adelaide_pd["Rain"])
ax[1].set_ylabel("Precipitation (mm d$^{-}$$^{1}$)", size=20)
ax[1].text(0.01, 0.9, "b)", ha='left', va='center', transform=ax[1].transAxes, fontsize=20)
for tick in ax[1].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[2].plot(daly_pd["Rain"])
ax[2].set_ylabel("Precipitation (mm d$^{-}$$^{1}$)", size=20)
ax[2].text(0.01, 0.9, "c)", ha='left', va='center', transform=ax[2].transAxes, fontsize=20)
for tick in ax[2].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[3].plot(dry_pd["Rain"])
ax[3].set_ylabel("Precipitation (mm d$^{-}$$^{1}$)", size=20)
ax[3].text(0.01, 0.9, "d)", ha='left', va='center', transform=ax[3].transAxes, fontsize=20)
for tick in ax[3].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[4].plot(sturt_pd["Rain"])
ax[4].set_ylabel("Precipitation (mm d$^{-}$$^{1}$)", size=20)
ax[4].text(0.01, 0.9, "e)", ha='left', va='center', transform=ax[4].transAxes, fontsize=20)
for tick in ax[4].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
for tick in ax[4].xaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure S7.1** Precipitation timeseries for a) Howard Springs, b) Adelaide River, c) Daly Uncleared, d) Dry River and e) Sturt Plains.

# %% [markdown]
# ### Temperature

# %%
fig, ax   = plt.subplots(nrows=5, ncols=1, figsize=(18, 20), sharex=True, sharey=True)   
ax[0].plot(howard_pd["TMax"], label = "Max. temperature")
ax[0].plot(howard_pd["TMin"], label = "Min. temperature")
ax[0].set_ylabel(r"Temperature ($^o$C)", size=20)
ax[0].text(0.01, 0.9, "a)", ha='left', va='center', transform=ax[0].transAxes, fontsize=20)
for tick in ax[0].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)    
ax[0].legend(prop={'size':15})
    
ax[1].plot(adelaide_pd["TMax"], label = "Max. temperature")
ax[1].plot(adelaide_pd["TMin"], label = "Min. temperature")
ax[1].set_ylabel(r"Temperature ($^o$C)", size=20)
ax[1].text(0.01, 0.9, "b)", ha='left', va='center', transform=ax[1].transAxes, fontsize=20)
for tick in ax[1].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
ax[1].legend(prop={'size':15})

ax[2].plot(daly_pd["TMax"], label = "Max. temperature")
ax[2].plot(daly_pd["TMin"], label = "Min. temperature")
ax[2].set_ylabel(r"Temperature ($^o$C)", size=20)
ax[2].text(0.01, 0.9, "c)", ha='left', va='center', transform=ax[2].transAxes, fontsize=20)
for tick in ax[2].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
ax[2].legend(prop={'size':15})

ax[3].plot(dry_pd["TMax"], label = "Max. temperature")
ax[3].plot(dry_pd["TMin"], label = "Min. temperature")
ax[3].set_ylabel(r"Temperature ($^o$C)", size=20)
ax[3].text(0.01, 0.9, "d)", ha='left', va='center', transform=ax[3].transAxes, fontsize=20)
for tick in ax[3].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
ax[3].legend(prop={'size':15})


ax[4].plot(sturt_pd["TMax"], label = "Max. temperature")
ax[4].plot(sturt_pd["TMin"], label = "Min. temperature")
ax[4].set_ylabel(r"Temperature ($^o$C)", size=20)
ax[4].text(0.01, 0.9, "e)", ha='left', va='center', transform=ax[4].transAxes, fontsize=20)
for tick in ax[4].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
for tick in ax[4].xaxis.get_major_ticks():
    tick.label.set_fontsize(20)
ax[4].legend(prop={'size':15})


plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-52c39c856c8e> in <module>
#      44
#      45
# ---> 46 plt.tight_layout()
#      47 plt.show()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1364     """
#    1365     fig = gcf()
# -> 1366     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1367
#    1368
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2273         kwargs = get_tight_layout_figure(
#    2274             self, self.axes, subplotspec_list, renderer,
# -> 2275             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2276         self.subplots_adjust(**kwargs)
#    2277
#
# ...

# %% [markdown]
# **Figure S7.2** Daily temperature timeseries with daily maximum temperatures in blue and daily minimum temperatures in red for a) Howard Springs, b) Adelaide River, c) Daly Uncleared, d) Dry River and e) Sturt Plains.

# %% [markdown]
# ### Incoming shortwave radiation

# %%
fig, ax   = plt.subplots(nrows=5, ncols=1, figsize=(18, 20), sharex=True, sharey=True)   
ax[0].plot(howard_pd["Radn"])
ax[0].set_ylabel(r"R$_{net}$ (MJ m$^{-2}$)", size=20)
ax[0].text(0.01, 0.9, "a)", ha='left', va='center', transform=ax[0].transAxes, fontsize=20)
for tick in ax[0].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[1].plot(adelaide_pd["Radn"])
ax[1].set_ylabel(r"R$_{net}$ (MJ m$^{-2}$)", size=20)
ax[1].text(0.01, 0.9, "b)", ha='left', va='center', transform=ax[1].transAxes, fontsize=20)
for tick in ax[1].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[2].plot(daly_pd["Radn"])
ax[2].set_ylabel(r"R$_{net}$ (MJ m$^{-2}$)", size=20)
ax[2].text(0.01, 0.9, "c)", ha='left', va='center', transform=ax[2].transAxes, fontsize=20)
for tick in ax[2].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[3].plot(dry_pd["Radn"])
ax[3].set_ylabel(r"R$_{net}$ (MJ m$^{-2}$)", size=20)
ax[3].text(0.01, 0.9, "d)", ha='left', va='center', transform=ax[3].transAxes, fontsize=20)
for tick in ax[3].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[4].plot(sturt_pd["Radn"])
ax[4].set_ylabel(r"R$_{net}$ (MJ m$^{-2}$)", size=20)
ax[4].text(0.01, 0.9, "e)", ha='left', va='center', transform=ax[4].transAxes, fontsize=20)
for tick in ax[4].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
for tick in ax[4].xaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure S7.3** Incoming shortwave radiation for a) Howard Springs, b) Adelaide River, c) Daly Uncleared, d) Dry River and e) Sturt Plains.

# %% [markdown]
# ### Vapour pressure

# %%
fig, ax   = plt.subplots(nrows=5, ncols=1, figsize=(18, 20), sharex=True, sharey=True)   
ax[0].plot(howard_pd["VP"])
ax[0].set_ylabel(r"Vap. press. (hPa)", size=20)
ax[0].text(0.01, 0.9, "a)", ha='left', va='center', transform=ax[0].transAxes, fontsize=20)
for tick in ax[0].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[1].plot(adelaide_pd["VP"])
ax[1].set_ylabel(r"Vap. press. (hPa)", size=20)
ax[1].text(0.01, 0.9, "b)", ha='left', va='center', transform=ax[1].transAxes, fontsize=20)
for tick in ax[1].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[2].plot(daly_pd["VP"])
ax[2].set_ylabel(r"Vap. press. (hPa)", size=20)
ax[2].text(0.01, 0.9, "c)", ha='left', va='center', transform=ax[2].transAxes, fontsize=20)
for tick in ax[2].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[3].plot(dry_pd["VP"])
ax[3].set_ylabel(r"Vap. press. (hPa)", size=20)
ax[3].text(0.01, 0.9, "d)", ha='left', va='center', transform=ax[3].transAxes, fontsize=20)
for tick in ax[3].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[4].plot(sturt_pd["VP"])
ax[4].set_ylabel(r"Vap. press. (hPa)", size=20)
ax[4].text(0.01, 0.9, "e)", ha='left', va='center', transform=ax[4].transAxes, fontsize=20)
for tick in ax[4].xaxis.get_major_ticks():
    tick.label.set_fontsize(20)
for tick in ax[4].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure S7.4** Vapour pressure for a) Howard Springs, b) Adelaide River, c) Daly Uncleared, d) Dry River and e) Sturt Plains.

# %% [markdown]
# ### Atmospheric pressure

# %%
fig, ax   = plt.subplots(nrows=5, ncols=1, figsize=(18, 20), sharex=True, sharey=True)   
ax[0].plot(howard_pd["Pres"])
ax[0].set_ylabel(r"Atm. press. (hPa)", size=20)
ax[0].text(0.01, 0.9, "a)", ha='left', va='center', transform=ax[0].transAxes, fontsize=20)
for tick in ax[0].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[1].plot(adelaide_pd["Pres"])
ax[1].set_ylabel(r"Atm. press.  (hPa)", size=20)
ax[1].text(0.01, 0.9, "b)", ha='left', va='center', transform=ax[1].transAxes, fontsize=20)
for tick in ax[1].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[2].plot(daly_pd["Pres"])
ax[2].set_ylabel(r"Atm. press.  (hPa)", size=20)
ax[2].text(0.01, 0.9, "c)", ha='left', va='center', transform=ax[2].transAxes, fontsize=20)
for tick in ax[2].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[3].plot(dry_pd["Pres"])
ax[3].set_ylabel(r"Atm. press.  (hPa)", size=20)
ax[3].text(0.01, 0.9, "d)", ha='left', va='center', transform=ax[3].transAxes, fontsize=20)
for tick in ax[3].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[4].plot(sturt_pd["Pres"])
ax[4].set_ylabel(r"Atm. press.  (hPa)", size=20)
ax[4].text(0.01, 0.9, "e)", ha='left', va='center', transform=ax[4].transAxes, fontsize=20)
for tick in ax[4].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
for tick in ax[4].xaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure S7.5** Atmospheric air pressure for a) Howard Springs, b) Adelaide River, c) Daly Uncleared, d) Dry River and e) Sturt Plains.

# %% [markdown]
# ### Atmospheric CO$_2$-levels

# %%
fig, ax   = plt.subplots(nrows=5, ncols=1, figsize=(18, 20), sharex=True, sharey=True)   
ax[0].plot(howard_pd["Ca"])
ax[0].set_ylabel(r"Atm. CO$_2$ (ppm)", size=20)
ax[0].text(0.01, 0.9, "a)", ha='left', va='center', transform=ax[0].transAxes, fontsize=20)
for tick in ax[0].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[1].plot(adelaide_pd["Ca"])
ax[1].set_ylabel(r"Atm.  CO$_2$ (ppm)", size=20)
ax[1].text(0.01, 0.9, "b)", ha='left', va='center', transform=ax[1].transAxes, fontsize=20)
for tick in ax[1].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[2].plot(daly_pd["Ca"])
ax[2].set_ylabel(r"Atm. CO$_2$ (ppm)", size=20)
ax[2].text(0.01, 0.9, "c)", ha='left', va='center', transform=ax[2].transAxes, fontsize=20)
for tick in ax[2].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
ax[3].plot(dry_pd["Ca"])
ax[3].set_ylabel(r"Atm. CO$_2$ (ppm)", size=20)
ax[3].text(0.01, 0.9, "d)", ha='left', va='center', transform=ax[3].transAxes, fontsize=20)
for tick in ax[3].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
print(np.mean(daly_pd["Ca"]  ))
      
ax[4].plot(sturt_pd["Ca"])
ax[4].set_ylabel(r"Atm. CO$_2$ (ppm)", size=20)
ax[4].text(0.01, 0.9, "e)", ha='left', va='center', transform=ax[4].transAxes, fontsize=20)
for tick in ax[4].xaxis.get_major_ticks():
    tick.label.set_fontsize(20)
for tick in ax[4].yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
    
plt.tight_layout()
plt.show()
# Out:
# 369.07854178674006

# %% [markdown]
# **Figure S7.6** Atmospheric CO$_2$-levels for a) Howard Springs, b) Adelaide River, c) Daly Uncleared, d) Dry River and e) Sturt Plains.

# %% [markdown]
# ## Mean Annual Values

# %%
def mean_annual_silo(meteofile, column, startyear, endyear, method):
    
    meteo_data = pd.read_csv(meteofile, skiprows = 43, delimiter=r"\s+", header=None )

   #make a pandas datetime series
    pddatetime = pd.to_datetime( meteo_data[2], format="%d-%m-%Y")

    #make a pandas index
    index = pd.DatetimeIndex( pddatetime)

    #replace index
    meteo_data.index = index
    
    #extract the variable of interest
    var = meteo_data[:][column]
    
    #print(var.resample("Y").sum())
    #calculate the mean annual value
    if(method == "mean_annual_sum"):
        MA_var = np.mean(var[ (var.index.year>=startyear) & (var.index.year<=endyear)].resample('A').sum() ) 

    
    if(method == "yearly_sums"):
        MA_var = var[ (var.index.year>=startyear) & (var.index.year<=endyear)].resample('A').sum() 
       
        
    
    return MA_var

# %%
def calc_netrad( weatherdata_file, lat, startyear, endyear ):
    
    #calculate net radiation, following FAO

    weatherdata = np.genfromtxt(weatherdata_file, names=True  )    
    
    #constants
    sigma = 4.903*10**-9 #Stefan-Boltzman constant [MJ K-4 m-2 day-1]
    Gsc = 0.0820 #solar constant [MJ m-2 hour-1]
    n = 10 #220/31 #sunshine hours
    N = 10 #maximum sunshine hours
    
    #get data from VOM-dailyweather
    Rs = weatherdata["Radn"]    # incoming solar radiation [MJ m-2 day-1]
    Tmax = weatherdata["TMax"]  # Celsius
    Tmin = weatherdata["TMin"]  # Celsius
    ea = weatherdata["VP"] /10  # kPa

    #define time and dates
    time = np.arange(datetime(int(weatherdata['Year'][0]),int(weatherdata['Month'][0]),int(weatherdata['Day'][0])), 
                  datetime(int(weatherdata['Year'][-1]),int(weatherdata['Month'][-1]),int(weatherdata['Day'][-1]))+timedelta(days=1), 
                  timedelta(days=1)).astype(datetime)
    time_pd = pd.date_range(time[0],periods=len( time ), freq='D')

    #day of year
    J = time_pd.dayofyear
    
    #inverse relative distance Earth-Sun
    dr =  1 + 0.033*np.cos(2*np.pi*J/365)  # [m?]

    phi=  (np.pi/180) * lat   #latitude [rad]
    
    #solar declination
    delta= 0.409*np.sin( (2*J*np.pi/365)  - 1.39 ) #[rad]
    
    #sunset hour angle
    ws =  np.arccos(-np.tan(phi)*np.tan(delta))

    #extraterrestrial radiation
    part1 = (24*60/np.pi) * Gsc * dr 
    part2 = ws*np.sin(phi)*np.sin(delta)
    part3 = np.cos(phi)*np.cos(delta)*np.sin(ws) 

    Ra =  part1*(part2+part3)  #[MJ m-2 hr-1]


    #Rso = Ra*z*0.75*2*10**-5
    Rso = Ra*(0.25+0.5*(n/N)) #clear-sky solar radiation [MJ m-2 day-1]

    Rns = (1-0.23) * Rs # shortwave radiation

    part1 = sigma*((Tmax+273.16)**4 + (Tmin+273.16)**4)/2
    part2 = 0.34-0.14*np.sqrt(ea)
    part3 = 1.35*Rs/Rso -0.35

    Rnl = part1 * part2 * part3 #net longwave radiation [MJ m-2 day-1]

    Rn = Rns - Rnl
    
    Rn_pd = pd.Series(Rn, index = time_pd)
    Rn_pd = Rn_pd[ (Rn_pd.index.year>=startyear) & (Rn_pd.index.year<=endyear)]
    
    return Rn_pd

# %%
MAP_hs = np.mean(howard_pd["Rain"].resample("A").sum())
MAP_ade = np.mean(adelaide_pd["Rain"].resample("A").sum())
MAP_litch = np.mean(litch_pd["Rain"].resample("A").sum())
MAP_daly = np.mean(daly_pd["Rain"].resample("A").sum())
MAP_dry = np.mean(dry_pd["Rain"].resample("A").sum())
MAP_sturt = np.mean(sturt_pd["Rain"].resample("A").sum())

# %%
MeanMaxT_hs = np.mean(howard_pd["TMax"].resample("A").max())
MeanMaxT_ade = np.mean(adelaide_pd["TMax"].resample("A").max())
MeanMaxT_litch = np.mean(litch_pd["TMax"].resample("A").max())
MeanMaxT_daly = np.mean(daly_pd["TMax"].resample("A").max())
MeanMaxT_dry = np.mean(dry_pd["TMax"].resample("A").max())
MeanMaxT_sturt = np.mean(sturt_pd["TMax"].resample("A").max())

# %%
MeanMinT_hs = np.mean(howard_pd["TMin"].resample("A").max())
MeanMinT_ade = np.mean(adelaide_pd["TMin"].resample("A").max())
MeanMinT_litch = np.mean(litch_pd["TMin"].resample("A").max())
MeanMinT_daly = np.mean(daly_pd["TMin"].resample("A").max())
MeanMinT_dry = np.mean(dry_pd["TMin"].resample("A").max())
MeanMinT_sturt = np.mean(sturt_pd["TMin"].resample("A").max())

# %%
EPade_fao = mean_annual_silo("../../data/Silo/adelaide.txt",  17, 1980, 2017, "mean_annual_sum")
EPdal_fao = mean_annual_silo("../../data/Silo/daly.txt",  17,1980, 2017, "mean_annual_sum")
EPdry_fao = mean_annual_silo("../../data/Silo/dry.txt",  17, 1980, 2017, "mean_annual_sum")
EPhs_fao = mean_annual_silo("../../data/Silo/howard.txt",  17,1980, 2017, "mean_annual_sum")
EPsturt_fao = mean_annual_silo("../../data/Silo/sturt.txt",  17,1980, 2017, "mean_annual_sum")

EP_fao = [EPhs_fao, EPade_fao, EPdal_fao, EPdry_fao, EPsturt_fao ]

# %%
Ep_P_hs = EPhs_fao / MAP_hs
Ep_P_ade = EPade_fao / MAP_ade
Ep_P_dal = EPdal_fao / MAP_daly
Ep_P_dry = EPdry_fao / MAP_dry
Ep_P_sturt = EPsturt_fao / MAP_sturt


Ep_P = [Ep_P_hs , Ep_P_ade, Ep_P_dal, Ep_P_dry, Ep_P_sturt]

# %%
rn_howard = calc_netrad("../../data/VOM_input/HowardSprings/dailyweather.prn", -12.49,1980, 2017)
rn_ade = calc_netrad("../../data/VOM_input/AdelaideRiver/dailyweather.prn", -13.077,1980, 2017)
rn_daly = calc_netrad("../../data/VOM_input/DalyUncleared/dailyweather.prn", -14.1592,1980, 2017)
rn_dry = calc_netrad("../../data/VOM_input/DryRiver/dailyweather.prn", -15.2587833333333 ,1980, 2017)
rn_sturt = calc_netrad("../../data/VOM_input/SturtPlains/dailyweather.prn", -17.1507,1980, 2017)

startyear = 1980
endyear = 2017

rn_howard_ma = np.mean(rn_howard[ (rn_howard.index.year>=startyear) & (rn_howard.index.year<=endyear)].resample('A').sum() )
rn_ade_ma = np.mean(rn_ade[ (rn_ade.index.year>=startyear) & (rn_ade.index.year<=endyear)].resample('A').sum() )
rn_daly_ma = np.mean(rn_daly[ (rn_daly.index.year>=startyear) & (rn_daly.index.year<=endyear)].resample('A').sum() )
rn_dry_ma = np.mean(rn_dry[ (rn_dry.index.year>=startyear) & (rn_dry.index.year<=endyear)].resample('A').sum() )
rn_sturt_ma = np.mean(rn_sturt[ (rn_sturt.index.year>=startyear) & (rn_sturt.index.year<=endyear)].resample('A').sum() )

rn_ma = [rn_howard_ma,  rn_ade_ma, rn_daly_ma, rn_dry_ma, rn_sturt_ma ]

# %%
RnLP_hs = rn_howard_ma / (MAP_hs*2.45 )
RnLP_ade = rn_ade_ma / (MAP_ade*2.45) 
RnLP_dal = rn_daly_ma / (MAP_daly*2.45) 
RnLP_dry = rn_dry_ma / (MAP_dry*2.45 )
RnLP_sturt = rn_sturt_ma / (MAP_sturt*2.45 )


RnLP = [RnLP_hs , RnLP_ade, RnLP_dal, RnLP_dry, RnLP_sturt]

# %%
data = [[ MAP_hs, EPhs_fao, RnLP_hs, rn_howard_ma,  MeanMinT_hs,  MeanMaxT_hs, ],
        [ MAP_ade, EPade_fao, RnLP_ade, rn_ade_ma, MeanMinT_ade, MeanMaxT_ade, ],
        [ MAP_daly, EPdal_fao, RnLP_dal, rn_daly_ma, MeanMinT_daly, MeanMaxT_daly],
        [MAP_dry, EPdry_fao, RnLP_dry, rn_dry_ma, MeanMinT_dry, MeanMaxT_dry],
        [MAP_sturt, EPsturt_fao, RnLP_sturt, rn_sturt_ma, MeanMinT_sturt, MeanMaxT_sturt], ]

rows = ('Howard Springs', 'Adelaide River', 'Daly Uncleared', 'Dry River', 'Sturt Plains')
columns = ( "prec. \n (mm year$^{-1}$)", 
            "pot. evap \n(mm year$^{-1}$)", 
            "aridity \n (-)", 
           "net radiation \n (MJ m$^{-2}$ year$^-$$^1$)", 
           "max.temp \n ($^o$C)",  "min.temp \n ($^o$C)"    )

n_rows = len(data)

cell_text = []
for row in range(n_rows):
    cell_text.append(['%1.2f' % x  for x in data[row]])


fig.patch.set_visible(False)
plt.axis('off')
plt.axis('tight')

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      colLabels=columns,
                      loc='center')

the_table.auto_set_font_size(False)
the_table.set_fontsize(16)
the_table.scale(2.5, 4)

plt.show()

# %% [markdown]
# **Table S7.1** Mean annual values of precipitation, daily maximum and daily minimum temperatures for the different sites.

# %% [markdown]
# ## Mean monthly values

# %%
def mean_monthly(inputfile, var ,startyear, endyear, method):

    #load data
    data = np.genfromtxt(inputfile, names=True)

    #make numpy arrays in the right units
    vals = np.array(data[var]) #mm/d

    #create series of pandas time
    tmod = np.arange(datetime(int(data['fyear'][0]),int(data['fmonth'][0]),int(data['fday'][0])), 
                      datetime(int(data['fyear'][-1]),int(data['fmonth'][-1]),int(data['fday'][-1]))+timedelta(days=1), 
                      timedelta(days=1)).astype(datetime)
                    
    #make pandas series
    vals_pd = pd.Series(vals, index=tmod)
                    
    if(method == "sum"):
        vals_tmp = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('M').sum()
        vals_ma = vals_tmp.groupby(vals_tmp.index.month).aggregate("mean")
    if(method == "max"):
        vals_ma = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('M').max().groupby('M').aggregate(mean)
    if(method == "min"):
        vals_ma = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('M').min().groupby('M').aggregate(mean)

    return vals_ma

# %%
precmon_howard = mean_monthly("../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "sum")
precmon_litch = mean_monthly("../../data/VOM_output/Litchfield/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "sum")
precmon_ade = mean_monthly("../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "sum")
precmon_daly = mean_monthly("../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "sum")
precmon_dry = mean_monthly("../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "sum")
precmon_sturt = mean_monthly("../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "sum")

#prec_all = [prec_howard, prec_litch, prec_ade, prec_daly, prec_dry, prec_sturt  ]

# %%
plt.figure()
sites = ['Howard Springs', 'Adelaide River', 'Daly Uncleared', 'Dry River', 'Sturt Plains']

fig, axes = plt.subplots(nrows=3, ncols=2,figsize = [15,20]) 
ax = axes.flat
fig.delaxes(ax[5])

precmon_howard.plot(kind='bar', color="blue", ax = ax[0])
ax[0].text(0, 1.03, sites[0], ha='left', va='center', transform=ax[0].transAxes, fontsize=20)
ax[0].text(-0.1, 1.08, "a)", ha='left', va='center', transform=ax[0].transAxes, fontsize=20)

precmon_ade.plot(kind='bar', color="blue", ax = ax[1])
ax[1].text(0, 1.03, sites[1], ha='left', va='center', transform=ax[1].transAxes, fontsize=20)
ax[1].text(-0.1, 1.08, "b)", ha='left', va='center', transform=ax[1].transAxes, fontsize=20)

precmon_daly.plot(kind='bar', color="blue", ax = ax[2])
ax[2].text(0, 1.03, sites[2], ha='left', va='center', transform=ax[2].transAxes, fontsize=20)
ax[2].text(-0.1, 1.08, "c)", ha='left', va='center', transform=ax[2].transAxes, fontsize=20)

precmon_dry.plot(kind='bar', color="blue", ax = ax[3])
ax[3].text(0, 1.03, sites[3], ha='left', va='center', transform=ax[3].transAxes, fontsize=20)
ax[3].text(-0.1, 1.08, "d)", ha='left', va='center', transform=ax[3].transAxes, fontsize=20)

precmon_sturt.plot(kind='bar', color="blue", ax = ax[4])
ax[4].text(0, 1.03, sites[4], ha='left', va='center', transform=ax[4].transAxes, fontsize=20)
ax[4].text(-0.1, 1.08, "e)", ha='left', va='center', transform=ax[4].transAxes, fontsize=20)

for i in range(len(sites)):
    ax[i].set_xlabel("Month", size=20)
    ax[i].set_ylabel("Prec. (mm month$^{-1}$)", size=20)
    for tick in ax[i].yaxis.get_major_ticks():
        tick.label.set_fontsize(20)
    for tick in ax[i].xaxis.get_major_ticks():
        tick.label.set_fontsize(20)

plt.show()

# %% [markdown]
# **Figure S7.7** Mean monthly precipitation for a) Howard Springs, b) Adelaide River, c) Daly Uncleared, d) Dry River and e) Sturt Plains.

# %% [markdown]
# ## Correlations climatic indeces

# %%
def dry_season(inputfile,startyear, endyear, method):

    #load data
    data = np.genfromtxt(inputfile, names=True)

    #make numpy arrays in the right units
    vals = np.array(data["Rain"]) #mm/d

    #create series of pandas time
    tmod = np.arange(datetime(int(data['Year'][0]),int(data['Month'][0]),int(data['Day'][0])), 
                      datetime(int(data['Year'][-1]),int(data['Month'][-1]),int(data['Day'][-1]))+timedelta(days=1), 
                      timedelta(days=1)).astype(datetime)
                    
    #make pandas series
    vals_pd = pd.Series(vals, index=tmod)
    vals_pd = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)]
    
    

    dry_period = np.zeros( len(np.arange(startyear,endyear+1))) #yearly dry periods
    i = 0
    for iyear in np.arange(startyear,endyear+1):
        tmp = vals_pd[vals_pd.index.year == iyear]
        dry_period[i] = tmp.value_counts().max()
        i = i + 1
    
    if(method == "mean_annual"):
        dryseason_duration =  np.mean(dry_period)
    if(method == "annual_values"):
        dryseason_duration =  dry_period
        
    return dryseason_duration

# %%
def rainfall_seasonality(inputfile,startyear, endyear, method):

    #load data
    data = np.genfromtxt(inputfile, names=True)

    #make numpy arrays in the right units
    vals = np.array(data["Rain"]) #mm/d

    #create series of pandas time
    tmod = np.arange(datetime(int(data['Year'][0]),int(data['Month'][0]),int(data['Day'][0])), 
                      datetime(int(data['Year'][-1]),int(data['Month'][-1]),int(data['Day'][-1]))+timedelta(days=1), 
                      timedelta(days=1)).astype(datetime)
                    
    #make pandas series
    vals_pd = pd.Series(vals, index=tmod)
    vals_pd = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)]

    
    if(method == "mean_annual"):
        Pma = np.mean(vals_pd.resample('A').sum() ) 
        Pmonth = vals_pd.resample('M').sum()
        Pmm = np.zeros(12) #mean monthly rainfall
        for i in range(1,13):
            Pmm_tmp = np.mean(Pmonth[Pmonth.index.month == i])
            Pmm[i-1] = Pmm_tmp


        seasonality =  (1/Pma) * np.sum( np.abs(Pmm - (Pma / 12)) )
        
    if(method == "annual_values"):
        Pma = vals_pd.resample('A').sum() 
        Pmonth = vals_pd.resample('M').sum()
        Pmm = np.zeros( (len(vals_pd.resample('A').sum()),12)) #mean monthly rainfall
        for i in range(1,13):
            Pmm_tmp = Pmonth[Pmonth.index.month == i]            
            Pmm[:, i-1] = Pmm_tmp

        seasonality = np.zeros(len(Pma))
        for i in range(0, len(Pma) ):
            seasonality[i] =  (1/Pma[i]) * np.sum( np.abs(Pmm[i,:] - (Pma[i] / 12)) )
        
    return seasonality

# %%
def mean_annual(inputfile, var ,startyear, endyear, method):

    #load data
    data = np.genfromtxt(inputfile, names=True)

    #make numpy arrays in the right units
    vals = np.array(data[var]) #mm/d

    #create series of pandas time
    tmod = np.arange(datetime(int(data['fyear'][0]),int(data['fmonth'][0]),int(data['fday'][0])), 
                      datetime(int(data['fyear'][-1]),int(data['fmonth'][-1]),int(data['fday'][-1]))+timedelta(days=1), 
                      timedelta(days=1)).astype(datetime)
                    
    #make pandas series
    vals_pd = pd.Series(vals, index=tmod)
                    
    if(method == "sum"):
        vals_ma = np.mean(vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('A').sum() ) 
    if(method == "max"):
        vals_ma = np.mean(vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('A').max() ) 
    if(method == "min"):
        vals_ma = np.mean(vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('A').min() )

    if(method == "yearly_sums"):
        vals_ma = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('A').sum() 

    if(method == "yearly_maxvals"):
        vals_ma = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('A').max() 
        
    if(method == "yearly_minvals"):
        vals_ma = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('A').min() 
    
    return vals_ma

# %%
prec_howard = mean_annual("../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "yearly_sums")
prec_ade = mean_annual("../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "yearly_sums")
prec_daly = mean_annual("../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "yearly_sums")
prec_dry = mean_annual("../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "yearly_sums")
prec_sturt = mean_annual("../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt", "rain" ,1995, 2015, "yearly_sums")

prec_all = [prec_howard, prec_ade, prec_daly, prec_dry, prec_sturt  ]

# %%
tmax_howard = mean_annual("../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt", "tairmax" ,1995, 2015, "yearly_maxvals")
tmax_ade = mean_annual("../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt", "tairmax" ,1995, 2015, "yearly_maxvals")
tmax_daly = mean_annual("../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt", "tairmax" ,1995, 2015, "yearly_maxvals")
tmax_dry = mean_annual("../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt", "tairmax" ,1995, 2015, "yearly_maxvals")
tmax_sturt = mean_annual("../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt", "tairmax" ,1995, 2015, "yearly_maxvals")

tmax_all = [tmax_howard,  tmax_ade, tmax_daly, tmax_dry, tmax_sturt  ]

# %%
seas_howard = rainfall_seasonality("../../data/VOM_input/HowardSprings/dailyweather.prn",1995, 2015, "annual_values")
seas_ade = rainfall_seasonality("../../data/VOM_input/AdelaideRiver/dailyweather.prn", 1995, 2015, "annual_values")
seas_daly = rainfall_seasonality("../../data/VOM_input/DalyUncleared/dailyweather.prn", 1995, 2015, "annual_values")
seas_dry = rainfall_seasonality("../../data/VOM_input/DryRiver/dailyweather.prn" ,1995, 2015, "annual_values")
seas_sturt = rainfall_seasonality("../../data/VOM_input/SturtPlains/dailyweather.prn", 1995, 2015, "annual_values")

seas = [seas_howard, seas_ade, seas_daly, seas_dry, seas_sturt ]

# %%
drydur_howard = dry_season("../../data/VOM_input/HowardSprings/dailyweather.prn",1995, 2015, "annual_values")
drydur_ade = dry_season("../../data/VOM_input/AdelaideRiver/dailyweather.prn", 1995, 2015, "annual_values")
drydur_daly = dry_season("../../data/VOM_input/DalyUncleared/dailyweather.prn", 1995, 2015, "annual_values")
drydur_dry = dry_season("../../data/VOM_input/DryRiver/dailyweather.prn" ,1995, 2015, "annual_values")
drydur_sturt = dry_season("../../data/VOM_input/SturtPlains/dailyweather.prn", 1995, 2015, "annual_values")

drydur = [drydur_howard, drydur_ade, drydur_daly, drydur_dry, drydur_sturt  ]

# %%
EPade_fao = mean_annual_silo("../../data/Silo/adelaide.txt",  17, 1995, 2015, "yearly_sums")
EPdal_fao = mean_annual_silo("../../data/Silo/daly.txt",  17,1995, 2015,"yearly_sums")
EPdry_fao = mean_annual_silo("../../data/Silo/dry.txt",  17, 1995, 2015,"yearly_sums")
EPhs_fao = mean_annual_silo("../../data/Silo/howard.txt",  17,1995, 2015,"yearly_sums")
EPsturt_fao = mean_annual_silo("../../data/Silo/sturt.txt",  17,1995, 2015,"yearly_sums")

EP_fao = [EPhs_fao, EPade_fao, EPdal_fao, EPdry_fao, EPsturt_fao ]

# %%
startyear = 1995
endyear = 2015

rn_howard_ma = rn_howard[ (rn_howard.index.year>=startyear) & (rn_howard.index.year<=endyear)].resample('A').sum() 
rn_ade_ma = rn_ade[ (rn_ade.index.year>=startyear) & (rn_ade.index.year<=endyear)].resample('A').sum() 
rn_daly_ma = rn_daly[ (rn_daly.index.year>=startyear) & (rn_daly.index.year<=endyear)].resample('A').sum() 
rn_dry_ma = rn_dry[ (rn_dry.index.year>=startyear) & (rn_dry.index.year<=endyear)].resample('A').sum() 
rn_sturt_ma = rn_sturt[ (rn_sturt.index.year>=startyear) & (rn_sturt.index.year<=endyear)].resample('A').sum() 

rn_ma = [rn_howard_ma,  rn_ade_ma, rn_daly_ma, rn_dry_ma, rn_sturt_ma ]

# %%
symbols = ['s', '>', '.','8', 'P','*']
colors = ['red', 'blue', 'green', 'gray', 'black', 'orange']
study_sites = ["Howard Springs", "Adelaide River", "Daly Uncleared", "Dry River", "Sturt Plains" ]

fig, axes   = plt.subplots(nrows=6, ncols=6, figsize=(15, 15))   
ax = axes.flat

for i in range(0, 5):
    ax[0].set_ylabel("Prec. (mm year$^-$$^1$)") 
    ax[0].scatter(  prec_all[i][0], prec_all[i][0] ,  marker=symbols[i],  s=140, color=colors[i], label = study_sites[i]  )
    N = 100
    G = np.zeros((N,N,3))+1
    ax[0].imshow(G)
    ax[0].legend(framealpha=1 )
    ax[0].axes.get_xaxis().set_visible(False)
    
    ax[1].scatter(  EP_fao[i], prec_all[i] ,  marker=symbols[i],  s=140, color=colors[i] )
    ax[2].scatter( rn_ma[i], prec_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[3].scatter( tmax_all[i], prec_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[4].scatter( drydur[i], prec_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[5].scatter( seas[i], prec_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    
    ax[6].set_ylabel("Pot. Evap. (mm year$^-$$^1$)") 
    ax[6].scatter(  prec_all[i], EP_fao[i] ,  marker=symbols[i],  s=140    , color=colors[i]  )
    ax[8].scatter( rn_ma[i], EP_fao[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[9].scatter( tmax_all[i], EP_fao[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[10].scatter( drydur[i], EP_fao[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[11].scatter( seas[i], EP_fao[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[7].imshow(G)
    ax[7].axes.get_xaxis().set_visible(False)
    ax[7].axes.get_yaxis().set_visible(False)
    
    ax[12].set_ylabel(r"Net rad. (MJ m$^{-2}$ year$^-$$^1$)") 
    ax[12].scatter( prec_all[i], rn_ma[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[13].scatter( EP_fao[i], rn_ma[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[15].scatter( tmax_all[i], rn_ma[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[16].scatter( drydur[i], rn_ma[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[17].scatter( seas[i], rn_ma[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[14].imshow(G)
    ax[14].axes.get_xaxis().set_visible(False)
    ax[14].axes.get_yaxis().set_visible(False)
    
    ax[18].set_ylabel(r"Max. temp. ($^o$ C)") 
    ax[18].scatter( prec_all[i], tmax_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[19].scatter( EP_fao[i], tmax_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[20].scatter( rn_ma[i], tmax_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[22].scatter( drydur[i], tmax_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[23].scatter( seas[i], tmax_all[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[21].imshow(G)
    ax[21].axes.get_xaxis().set_visible(False)
    ax[21].axes.get_yaxis().set_visible(False)
    
    ax[24].set_ylabel(r"Length dry season (days)") 
    ax[24].scatter(  prec_all[i], drydur[i] ,  marker=symbols[i],  s=140    , color=colors[i]  )
    ax[25].scatter( EP_fao[i], drydur[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[26].scatter(  rn_ma[i], drydur[i] ,  marker=symbols[i],  s=140    , color=colors[i]  )
    ax[27].scatter( tmax_all[i], drydur[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[29].scatter( seas[i], drydur[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[28].imshow(G)
    ax[28].axes.get_xaxis().set_visible(False)
    ax[28].axes.get_yaxis().set_visible(False)
    
    ax[30].set_ylabel(r"Rain Seasonality (-)") 
    ax[30].scatter( prec_all[i], seas[i] ,   marker=symbols[i],  s=140   , color=colors[i]  )
    ax[31].scatter( EP_fao[i], seas[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[32].scatter( rn_ma[i], seas[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[33].scatter( tmax_all[i], seas[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[34].scatter( drydur[i], seas[i] ,   marker=symbols[i],  s=140    , color=colors[i]  )
    ax[35].imshow(G)
    ax[35].axes.get_xaxis().set_visible(False)
    ax[35].axes.get_yaxis().set_visible(False)
    
    ax[30].set_xlabel("Prec. (mm year$^-$$^1$)") 
    ax[31].set_xlabel("Pot. Evap. (mm year$^-$$^1$)") 
    ax[32].set_xlabel(r"Net rad. (MJ m$^{-2}$ year$^-$$^1$)") 
    ax[33].set_xlabel(r"Max. temp. ($^o$ C)") 
    ax[34].set_xlabel("Length dry season (days)") 
    ax[35].set_xlabel("Rain Seasonality (-)") 
    
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure S7.8** Relations for yearly values of precipitation (first row, first column), potential evaporation (second row, column), net radiation (third row, column), maximum temperatures (fourth row, column), length of the dry season (fifth row, column) and rainfall seasonality (sixth row, column).

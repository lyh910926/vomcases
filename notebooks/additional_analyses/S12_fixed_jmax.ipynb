# %% [markdown]
# # Fixed electron transport capacity
# In order to assess compensatory effects, the electron transport capacity J${max25} is fixed and compared to the standard model runs.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta, date
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from scipy.misc import imread
import matplotlib.cbook as cbook

# %% [markdown]
# ## Timeseries

# %% [markdown]
# ### Howard Springs

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/HowardSprings/sce_best/results_daily.txt \
../../data/VOM_output/HowardSprings/freedrainage_cpcff1.0/sce_best/results_daily.txt \
-ys 2001 -ye 2006 \
--i2015 ../../data/VOM_output/additional_analyses/comp2015/0_benchmark/resultsdaily.txt \
--assobs ../../data/DINGO/GPPdaily_howard.txt --assobs_qc ../../data/DINGO_QC/FcQ_howard.txt \
--eobs_qc ../../data/DINGO_QC/FeQ_howard.txt --eobs ../../data/DINGO/Ea_howard.txt \
--pcobs ../../data/fPAR/fpar_howard_v5.txt \
--pcobsdates ../../data/fPAR/dates_v5 --labels VOM  --legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "VOM" --figsize 16 19 --hpad -3 --sharex --labelsize 20 \
--var "evaptot" "etmt" "etmg" "esoil" "asstot" "asst" "assg" "pc" \
--figsize 16 19 --hpad -2 --sharex --labelsize 20 --wpad 2 \
--ymax 10 5 5 5 1.5 1.0 1.0 100 \
--ymin 0 0 0 0 0 0 0 0 \
--labels "fixed Jmax" "predicted Jmax"

# %% [markdown]
# **Figure S12.1.** Comparison for Howard Springs from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use a fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) ET, b) transpiration perennials (trees), c) transpiration seasonals (grasses), d) soil evaporation, e) GPP, f) GPP perennials (trees), g) GPP seasonals (grasses), all smoothed with a moving average of 7 days, and h) projective cover. The daily average quality flags of the fluxtower observations are shown in dashed lines with a value of 100 when a day is completely gap-filled and 1 when it is observed.

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/HowardSprings/sce_best/results_daily.txt \
../../data/VOM_output/HowardSprings/freedrainage_cpcff1.0/sce_best/results_daily.txt \
--var "jmax25g" "jmax25t" "lambdag" "lambdat"  \
-ys 2001 -ye 2006 \
--i2015 ../../data/VOM_output/additional_analyses/comp2015/0_benchmark/resultsdaily.txt \
--ymax 0.0005 0.0005 5000 5000  \
--ymin 0 0 0 0 \
--pcobsdates ../../data/fPAR/dates_v5 --legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "fixed Jmax" "predicted Jmax" \
--figsize 16 10 --hpad 2 --sharex --labelsize 20

# %% [markdown]
# **Figure S12.2.** Comparison for Howard Springs from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) the electron transport capacity at 25 $^o$C for seasonal grasses (J$_{max25,s}$), b) the electron transport capacity at 25 $^o$C for perennials trees (J$_{max25,p}$), d) transpiration seasonals (grasses), d)  the daily slope ($\lambda_s$) between assimilation and transpiration of the seasonal grasses, e) the daily slope ($\lambda_p$) between assimilation and transpiration of the perennials (trees).

# %% [markdown]
# ### Adelaide River

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/AdelaideRiver/sce_best/results_daily.txt \
../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.0/sce_best/results_daily.txt \
-ys 2001 -ye 2006 \
--assobs ../../data/DINGO/GPPdaily_adelaide.txt --assobs_qc ../../data/DINGO_QC/FcQ_adelaide.txt \
--eobs_qc ../../data/DINGO_QC/FeQ_adelaide.txt --eobs ../../data/DINGO/Ea_adelaide.txt \
--pcobs ../../data/fPAR/fpar_adelaide_v5.txt \
--pcobsdates ../../data/fPAR/dates_v5 --labels VOM  --legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "VOM" --figsize 16 19 --hpad -3 --sharex --labelsize 20 \
--var "evaptot" "etmt" "etmg" "esoil" "asstot" "asst" "assg" "pc" \
--figsize 16 19 --hpad -2 --sharex --labelsize 20 --wpad 2 \
--ymax 10 5 5 5 1.5 1.0 1.0 100 \
--ymin 0 0 0 0 0 0 0 0 \
--labels "fixed Jmax" "predicted Jmax"

# %% [markdown]
# **Figure S12.3.** Comparison for Adelaide River from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use a fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) ET, b) transpiration perennials (trees), c) transpiration seasonals (grasses), d) soil evaporation, e) GPP, f) GPP perennials (trees), g) GPP seasonals (grasses), all smoothed with a moving average of 7 days, and h) projective cover. The daily average quality flags of the fluxtower observations are shown in dashed lines with a value of 100 when a day is completely gap-filled and 1 when it is observed.

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/AdelaideRiver/sce_best/results_daily.txt \
../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.0/sce_best/results_daily.txt \
--var "jmax25g" "jmax25t" "lambdag" "lambdat"  \
-ys 2001 -ye 2006 \
--ymax 0.0005 0.0005 5000 5000  \
--ymin 0 0 0 0 \
--legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "fixed Jmax" "predicted Jmax" \
--figsize 16 10 --hpad 2 --sharex --labelsize 20

# %% [markdown]
# **Figure S12.4.** Comparison for Adelaide River from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) the electron transport capacity at 25 $^o$C for seasonal grasses (J$_{max25,s}$), b) the electron transport capacity at 25 $^o$C for perennials trees (J$_{max25,p}$), d) transpiration seasonals (grasses), d)  the daily slope ($\lambda_s$) between assimilation and transpiration of the seasonal grasses, e) the daily slope ($\lambda_p$) between assimilation and transpiration of the perennials (trees).

# %% [markdown]
# ### Daly Uncleared

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/DalyUncleared/sce_best/results_daily.txt \
../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.0/sce_best/results_daily.txt \
-ys 2001 -ye 2006 \
--assobs ../../data/DINGO/GPPdaily_daly.txt --assobs_qc ../../data/DINGO_QC/FcQ_daly.txt \
--eobs_qc ../../data/DINGO_QC/FeQ_daly.txt --eobs ../../data/DINGO/Ea_daly.txt \
--pcobs ../../data/fPAR/fpar_daly_v5.txt \
--pcobsdates ../../data/fPAR/dates_v5 --labels VOM  --legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "VOM" --figsize 16 19 --hpad -3 --sharex --labelsize 20 \
--var "evaptot" "etmt" "etmg" "esoil" "asstot" "asst" "assg" "pc" \
--figsize 16 19 --hpad -2 --sharex --labelsize 20 --wpad 2 \
--ymax 10 5 5 5 1.5 1.0 1.0 100 \
--ymin 0 0 0 0 0 0 0 0 \
--labels "fixed Jmax" "predicted Jmax"

# %% [markdown]
# **Figure S12.5.** Comparison for Daly Uncleared from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use a fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) ET, b) transpiration perennials (trees), c) transpiration seasonals (grasses), d) soil evaporation, e) GPP, f) GPP perennials (trees), g) GPP seasonals (grasses), all smoothed with a moving average of 7 days, and h) projective cover. The daily average quality flags of the fluxtower observations are shown in dashed lines with a value of 100 when a day is completely gap-filled and 1 when it is observed.

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/DalyUncleared/sce_best/results_daily.txt \
../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.0/sce_best/results_daily.txt \
--var "jmax25g" "jmax25t" "lambdag" "lambdat"  \
-ys 2001 -ye 2006 \
--ymax 0.0005 0.0005 5000 5000  \
--ymin 0 0 0 0 \
--legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "fixed Jmax" "predicted Jmax" \
--figsize 16 10 --hpad 2 --sharex --labelsize 20

# %% [markdown]
# **Figure S12.6.** Comparison for Howard Springs from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) the electron transport capacity at 25 $^o$C for seasonal grasses (J$_{max25,s}$), b) the electron transport capacity at 25 $^o$C for perennials trees (J$_{max25,p}$), d) transpiration seasonals (grasses), d)  the daily slope ($\lambda_s$) between assimilation and transpiration of the seasonal grasses, e) the daily slope ($\lambda_p$) between assimilation and transpiration of the perennials (trees).

# %% [markdown]
# ### Dry River

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/DryRiver/sce_best/results_daily.txt \
../../data/VOM_output/DryRiver/freedrainage_cpcff1.0/sce_best/results_daily.txt \
-ys 2001 -ye 2006 \
--assobs ../../data/DINGO/GPPdaily_dry.txt --assobs_qc ../../data/DINGO_QC/FcQ_dry.txt \
--eobs_qc ../../data/DINGO_QC/FeQ_dry.txt --eobs ../../data/DINGO/Ea_dry.txt \
--pcobs ../../data/fPAR/fpar_daly_v5.txt \
--pcobsdates ../../data/fPAR/dates_v5 --labels VOM  --legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "VOM" --figsize 16 19 --hpad -3 --sharex --labelsize 20 \
--var "evaptot" "etmt" "etmg" "esoil" "asstot" "asst" "assg" "pc" \
--figsize 16 19 --hpad -2 --sharex --labelsize 20 --wpad 2 \
--ymax 10 5 5 5 1.5 1.0 1.0 100 \
--ymin 0 0 0 0 0 0 0 0 \
--labels "fixed Jmax" "predicted Jmax"

# %% [markdown]
# **Figure S12.7.** Comparison for Dry River from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use a fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) ET, b) transpiration perennials (trees), c) transpiration seasonals (grasses), d) soil evaporation, e) GPP, f) GPP perennials (trees), g) GPP seasonals (grasses), all smoothed with a moving average of 7 days, and h) projective cover. The daily average quality flags of the fluxtower observations are shown in dashed lines with a value of 100 when a day is completely gap-filled and 1 when it is observed.

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/DryRiver/sce_best/results_daily.txt \
../../data/VOM_output/DryRiver/freedrainage_cpcff1.0/sce_best/results_daily.txt \
--var "jmax25g" "jmax25t" "lambdag" "lambdat"  \
-ys 2001 -ye 2006 \
--ymax 0.0005 0.0005 5000 5000  \
--ymin 0 0 0 0 \
--legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "fixed Jmax" "predicted Jmax" \
--figsize 16 10 --hpad 2 --sharex --labelsize 20

# %% [markdown]
# **Figure S12.8.** Comparison for Dry River from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) the electron transport capacity at 25 $^o$C for seasonal grasses (J$_{max25,s}$), b) the electron transport capacity at 25 $^o$C for perennials trees (J$_{max25,p}$), d) transpiration seasonals (grasses), d)  the daily slope ($\lambda_s$) between assimilation and transpiration of the seasonal grasses, e) the daily slope ($\lambda_p$) between assimilation and transpiration of the perennials (trees).

# %% [markdown]
# ### Sturt Plains

# %% [markdown]
# **Figure S12.1.** Comparison of electron transport capacities for trees for the VOM with a fixed Jmax25 (red), predicted Jmax25 (gray) for a) Howard Springs, b) Litchfield, c) Adelaide River d) Daly Uncleared, e) Dry River and f) Sturt Plains.

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/SturtPlains/sce_best/results_daily.txt \
../../data/VOM_output/SturtPlains/freedrainage_cpcff1.0/sce_best/results_daily.txt \
-ys 2001 -ye 2006 \
--assobs ../../data/DINGO/GPPdaily_sturt.txt --assobs_qc ../../data/DINGO_QC/FcQ_sturt.txt \
--eobs_qc ../../data/DINGO_QC/FeQ_sturt.txt --eobs ../../data/DINGO/Ea_sturt.txt \
--pcobs ../../data/fPAR/fpar_sturt_v5.txt \
--pcobsdates ../../data/fPAR/dates_v5 --labels VOM  --legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "VOM" --figsize 16 19 --hpad -3 --sharex --labelsize 20 \
--var "evaptot" "etmt" "etmg" "esoil" "asstot" "asst" "assg" "pc" \
--figsize 16 19 --hpad -2 --sharex --labelsize 20 --wpad 2 \
--ymax 10 5 5 5 1.5 1.0 1.0 100 \
--ymin 0 0 0 0 0 0 0 0 \
--labels "fixed Jmax" "predicted Jmax"

# %% [markdown]
# **Figure S12.9.** Comparison for Daly Uncleared from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use a fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) ET, b) transpiration perennials (trees), c) transpiration seasonals (grasses), d) soil evaporation, e) GPP, f) GPP perennials (trees), g) GPP seasonals (grasses), all smoothed with a moving average of 7 days, and h) projective cover. The daily average quality flags of the fluxtower observations are shown in dashed lines with a value of 100 when a day is completely gap-filled and 1 when it is observed.

# %%
# %run ../../src_py/plot_timeseries.py \
-i ../../data/VOM_output/additional_analyses/fixed_jmax/SturtPlains/sce_best/results_daily.txt \
../../data/VOM_output/SturtPlains/freedrainage_cpcff1.0/sce_best/results_daily.txt \
--var "jmax25g" "jmax25t" "lambdag" "lambdat"  \
-ys 2001 -ye 2006 \
--ymax 0.0005 0.0005 5000 5000  \
--ymin 0 0 0 0 \
--legend \
--xloc_title -0.13 --yloc_title 1.05 --size_title 24 --moving_average 7  --colors red black gray \
--labels "fixed Jmax" "predicted Jmax" \
--figsize 16 10 --hpad 2 --sharex --labelsize 20

# %% [markdown]
# **Figure S12.10.** Comparison for Sturt Plains from 2001-2006 (subset from 1980-2017) between the results of Schymanski et al. (2015) (green) and VOM simulations that use fixed electron transport capacity J$_{max25}$ (red), and the new VOM modelling results (black), for a) the electron transport capacity at 25 $^o$C for seasonal grasses (J$_{max25,s}$), b) the electron transport capacity at 25 $^o$C for perennials trees (J$_{max25,p}$), d) transpiration seasonals (grasses), d)  the daily slope ($\lambda_s$) between assimilation and transpiration of the seasonal grasses, e) the daily slope ($\lambda_p$) between assimilation and transpiration of the perennials (trees).

# %% [markdown]
# ##  Partitioning fluxes

# %%
def fluxpartitions(inputfile, startyear, endyear, startwet, endwet, startdry, enddry):

    #load data
    data = np.genfromtxt(inputfile, names=True)

    #make numpy arrays in the right units
    esoil = 1000*np.array(data["esoil"]) #mm/d
    etmt = 1000*np.array(data["etmt"])   #mm/d
    etmg = 1000*np.array(data["etmg"])   #mm/d
    assg = np.array(data["assg"])        #mol/m2/d
    asst = np.array(data["asst"])        #mol/m2/d

    #create series of pandas time
    tmod = np.arange(datetime(int(data['fyear'][0]),int(data['fmonth'][0]),int(data['fday'][0])), 
                      datetime(int(data['fyear'][-1]),int(data['fmonth'][-1]),int(data['fday'][-1]))+timedelta(days=1), 
                      timedelta(days=1)).astype(datetime)
                    
    #make pandas series
    esoil_pd = pd.Series(esoil, index=tmod)
    etmt_pd = pd.Series(etmt, index=tmod)
    etmg_pd = pd.Series(etmg, index=tmod)
    assg_pd = pd.Series(assg, index=tmod)
    asst_pd = pd.Series(asst, index=tmod)
                    
    esoil_ma = np.mean(esoil_pd[ (esoil_pd.index.year>=startyear) & (esoil_pd.index.year<=endyear)].resample('A').sum() ) 
    etmt_ma = np.mean(etmt_pd[(etmt_pd.index.year>=startyear) & (etmt_pd.index.year<=endyear)].resample('A').sum() ) 
    etmg_ma = np.mean(etmg_pd[(etmg_pd.index.year>=startyear) & (etmg_pd.index.year<=endyear)].resample('A').sum() ) 
    assg_ma = np.mean(assg_pd[(assg_pd.index.year>=startyear) & (assg_pd.index.year<=endyear)].resample('A').sum() ) 
    asst_ma = np.mean(asst_pd[(asst_pd.index.year>=startyear) & (asst_pd.index.year<=endyear)].resample('A').sum() ) 

    esoil_mm = esoil_pd.resample('M').sum()
    etmt_mm = etmt_pd.resample('M').sum()
    etmg_mm = etmg_pd.resample('M').sum()
    assg_mm = assg_pd.resample('M').sum()
    asst_mm = asst_pd.resample('M').sum()

    esoil_dry = 0.0
    etmt_dry = 0.0
    etmg_dry = 0.0
    asst_dry = 0.0
    assg_dry = 0.0
    
    esoil_wet = 0.0
    etmt_wet = 0.0
    etmg_wet = 0.0
    asst_wet = 0.0
    assg_wet = 0.0
    
    esoil_wet2dry = 0.0
    etmt_wet2dry = 0.0
    etmg_wet2dry = 0.0
    asst_wet2dry = 0.0
    assg_wet2dry = 0.0
    
    esoil_dry2wet = 0.0
    etmt_dry2wet = 0.0
    etmg_dry2wet = 0.0
    asst_dry2wet = 0.0
    assg_dry2wet = 0.0
    
    for i in range(1,13):
        
        if startwet < endwet:        
            if( (i >= startwet) &  (i <= endwet)  ):
                esoil_wet = esoil_wet + np.mean( esoil_mm[esoil_mm.index.month == i] )
                etmt_wet = etmt_wet + np.mean( etmt_mm[etmt_mm.index.month == i] )
                etmg_wet = etmg_wet + np.mean( etmg_mm[etmg_mm.index.month == i] )
                assg_wet = assg_wet + np.mean( assg_mm[asst_mm.index.month == i] )
                asst_wet = asst_wet + np.mean( asst_mm[asst_mm.index.month == i] )
                
        if startdry < enddry:        
            if( (i >= startdry) &  (i <= enddry)  ):                
                esoil_dry = esoil_dry + np.mean( esoil_mm[esoil_mm.index.month == i] )
                etmt_dry = etmt_dry + np.mean( etmt_mm[etmt_mm.index.month == i] )
                etmg_dry = etmg_dry + np.mean( etmg_mm[etmg_mm.index.month == i] )
                assg_dry = assg_dry + np.mean( assg_mm[asst_mm.index.month == i] )
                asst_dry = asst_dry + np.mean( asst_mm[asst_mm.index.month == i] )                    


        if startwet > endwet:        
            if( (i >= startwet) |  (i <= endwet)  ):
                esoil_wet = esoil_wet + np.mean( esoil_mm[esoil_mm.index.month == i] )
                etmt_wet = etmt_wet + np.mean( etmt_mm[etmt_mm.index.month == i] )
                etmg_wet = etmg_wet + np.mean( etmg_mm[etmg_mm.index.month == i] )
                assg_wet = assg_wet + np.mean( assg_mm[asst_mm.index.month == i] )
                asst_wet = asst_wet + np.mean( asst_mm[asst_mm.index.month == i] )        

        if startdry > enddry:        
            if( (i >= startdry) |  (i <= enddry)  ):                
                esoil_dry = esoil_dry + np.mean( esoil_mm[esoil_mm.index.month == i] )
                etmt_dry = etmt_dry + np.mean( etmt_mm[etmt_mm.index.month == i] )
                etmg_dry = etmg_dry + np.mean( etmg_mm[etmg_mm.index.month == i] )
                assg_dry = assg_dry + np.mean( assg_mm[asst_mm.index.month == i] )
                asst_dry = asst_dry + np.mean( asst_mm[asst_mm.index.month == i] ) 
  
        #dry2wet-period
        if enddry < startwet:        
            if( (i > enddry) &  (i < startwet)  ):
                esoil_dry2wet = esoil_dry2wet + np.mean( esoil_mm[esoil_mm.index.month == i] )
                etmt_dry2wet = etmt_dry2wet + np.mean( etmt_mm[etmt_mm.index.month == i] )
                etmg_dry2wet = etmg_dry2wet + np.mean( etmg_mm[etmg_mm.index.month == i] )
                assg_dry2wet = assg_dry2wet + np.mean( assg_mm[asst_mm.index.month == i] )
                asst_dry2wet = asst_dry2wet + np.mean( asst_mm[asst_mm.index.month == i] )
                
        if startwet < enddry:        
            if( (i > enddry) |  (i < startwet)  ):
                esoil_dry2wet = esoil_dry2wet + np.mean( esoil_mm[esoil_mm.index.month == i] )
                etmt_dry2wet = etmt_dry2wet + np.mean( etmt_mm[etmt_mm.index.month == i] )
                etmg_dry2wet = etmg_dry2wet + np.mean( etmg_mm[etmg_mm.index.month == i] )
                assg_dry2wet = assg_dry2wet + np.mean( assg_mm[asst_mm.index.month == i] )
                asst_dry2wet = asst_dry2wet + np.mean( asst_mm[asst_mm.index.month == i] )
    
        #wet2dry-period
        if endwet < startdry:
            if( (i > endwet) &  (i < startdry)  ):
                esoil_wet2dry = esoil_wet2dry + np.mean( esoil_mm[esoil_mm.index.month == i] )
                etmt_wet2dry = etmt_wet2dry + np.mean( etmt_mm[etmt_mm.index.month == i] )
                etmg_wet2dry = etmg_wet2dry + np.mean( etmg_mm[etmg_mm.index.month == i] )
                assg_wet2dry = assg_wet2dry + np.mean( assg_mm[asst_mm.index.month == i] )
                asst_wet2dry = asst_wet2dry + np.mean( asst_mm[asst_mm.index.month == i] )          
            
        if startdry < endwet:
            if( (i > endwet) |  (i < startdry)  ):
                esoil_wet2dry = esoil_wet2dry + np.mean( esoil_mm[esoil_mm.index.month == i] )
                etmt_wet2dry = etmt_wet2dry + np.mean( etmt_mm[etmt_mm.index.month == i] )
                etmg_wet2dry = etmg_wet2dry + np.mean( etmg_mm[etmg_mm.index.month == i] )
                assg_wet2dry = assg_wet2dry + np.mean( assg_mm[asst_mm.index.month == i] )
                asst_wet2dry = asst_wet2dry + np.mean( asst_mm[asst_mm.index.month == i] )
    
    
    
    result = [esoil_ma, etmt_ma, etmg_ma, assg_ma, asst_ma]
    result_wet = [esoil_wet, etmt_wet, etmg_wet, assg_wet, asst_wet]
    result_dry = [esoil_dry, etmt_dry, etmg_dry, assg_dry, asst_dry]
    result_dry2wet = [esoil_dry2wet, etmt_dry2wet, etmg_dry2wet, assg_dry2wet, asst_dry2wet]
    result_wet2dry = [esoil_wet2dry, etmt_wet2dry, etmg_wet2dry, assg_wet2dry, asst_wet2dry]
   
    return result, result_wet, result_dry, result_dry2wet, result_wet2dry

# %%
def mean_annual_dingo(inputfile, startyear, endyear, startwet, endwet, startdry, enddry):

    #load data
    
    data = np.loadtxt(inputfile, usecols=2) #mm/d
    
    #create series of pandas time
    tflux_tmp = np.genfromtxt(inputfile, usecols=0, dtype=np.str )#mm/d
    tflux = pd.date_range(tflux_tmp[0], tflux_tmp[-1], freq='D')
                    
    #make pandas series
    vals_pd = pd.Series(data, index=tflux)                    
    vals_ma = np.mean(vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('A').sum() ) 

    vals_mm = vals_pd[ (vals_pd.index.year>=startyear) & (vals_pd.index.year<=endyear)].resample('M').sum()
    vals_dry = 0.0
    vals_wet = 0.0
    vals_wet2dry = 0.0
    vals_dry2wet = 0.0

    for i in range(1,13):
        
        if startwet < endwet:        
            if( (i >= startwet) &  (i <= endwet)  ):
                vals_wet = vals_wet + np.mean( vals_mm[vals_mm.index.month == i] )
                
        if startdry < enddry:        
            if( (i >= startdry) &  (i <= enddry)  ):
                vals_dry = vals_dry + np.mean( vals_mm[vals_mm.index.month == i] )          
               
    
        if startwet > endwet:        
            if( (i >= startwet) |  (i <= endwet)  ):
                vals_wet = vals_wet + np.mean( vals_mm[vals_mm.index.month == i] )
                
        if startdry > enddry:    
            if( (i >= startdry) |  (i <= enddry)  ):
                vals_dry = vals_dry + np.mean( vals_mm[vals_mm.index.month == i] )
                
        #dry2wet-period
        if enddry < startwet:        
            if( (i > enddry) &  (i < startwet)  ):
                vals_dry2wet = vals_dry2wet + np.mean( vals_mm[vals_mm.index.month == i] )
                
        if startwet < enddry:        
            if( (i > enddry) |  (i < startwet)  ):
                vals_dry2wet = vals_dry2wet + np.mean( vals_mm[vals_mm.index.month == i] )
    
        #wet2dry-period
        if endwet < startdry:
            if( (i > endwet) &  (i < startdry)  ):
                vals_wet2dry = vals_wet2dry + np.mean( vals_mm[vals_mm.index.month == i] )        
            
        if startdry < endwet:
            if( (i > endwet) |  (i < startdry)  ):
                vals_wet2dry = vals_wet2dry + np.mean( vals_mm[vals_mm.index.month == i] )                
    
    result = [vals_ma, vals_wet, vals_dry, vals_dry2wet, vals_wet2dry]
    
    return result

# %%
Ea_howard_obs = mean_annual_dingo("../../data/DINGO/Ea_howard.txt", 2002, 2017, 12, 3, 5, 9 )
Ea_litch_obs = mean_annual_dingo("../../data/DINGO/Ea_litch.txt", 2016, 2018, 12, 3, 5, 9 )
Ea_adelaide_obs = mean_annual_dingo("../../data/DINGO/Ea_adelaide.txt",  2007, 2008, 12, 3, 5, 9 )
Ea_daly_obs = mean_annual_dingo("../../data/DINGO/Ea_daly.txt", 2008, 2017, 12, 3, 5, 9 )
Ea_dry_obs = mean_annual_dingo("../../data/DINGO/Ea_dry.txt", 2009, 2017, 12, 3, 5, 9 )
Ea_sturt_obs = mean_annual_dingo("../../data/DINGO/Ea_sturt.txt", 2009, 2017, 12, 3, 5, 9 )

etot_dingo = [Ea_howard_obs[0], Ea_litch_obs[0], Ea_adelaide_obs[0], Ea_daly_obs[0], Ea_dry_obs[0], Ea_sturt_obs[0]    ]
ewet_dingo = [Ea_howard_obs[1], Ea_litch_obs[1], Ea_adelaide_obs[1], Ea_daly_obs[1], Ea_dry_obs[1],Ea_sturt_obs[1]    ]
edry_dingo = [Ea_howard_obs[2], Ea_litch_obs[2], Ea_adelaide_obs[2], Ea_daly_obs[2], Ea_dry_obs[2],Ea_sturt_obs[2]   ]
edry2wet_dingo = [Ea_howard_obs[3], Ea_litch_obs[3], Ea_adelaide_obs[3], Ea_daly_obs[3], Ea_dry_obs[3],Ea_sturt_obs[3]   ]
ewet2dry_dingo = [Ea_howard_obs[4], Ea_litch_obs[4], Ea_adelaide_obs[4], Ea_daly_obs[4], Ea_dry_obs[4],Ea_sturt_obs[4]   ]

# %%
GPP_howard_obs = mean_annual_dingo("../../data/DINGO/GPPdaily_howard.txt", 2002, 2017, 12, 3, 5, 9 )
GPP_litch_obs = mean_annual_dingo("../../data/DINGO/GPPdaily_litch.txt", 2016, 2018, 12, 3, 5, 9 )
GPP_adelaide_obs = mean_annual_dingo("../../data/DINGO/GPPdaily_adelaide.txt", 2007, 2008, 12, 3, 5, 9 )
GPP_daly_obs = mean_annual_dingo("../../data/DINGO/GPPdaily_daly.txt", 2008, 2017, 12, 3, 5, 9 )
GPP_dry_obs = mean_annual_dingo("../../data/DINGO/GPPdaily_dry.txt", 2009, 2017, 12, 3, 5, 9 )
GPP_sturt_obs =mean_annual_dingo("../../data/DINGO/GPPdaily_sturt.txt", 2009, 2017, 12, 3, 5, 9 ) 

gpptot_dingo = [GPP_howard_obs[0]*-1.0, GPP_litch_obs[0]*-1.0, GPP_adelaide_obs[0]*-1.0, GPP_daly_obs[0]*-1.0, GPP_dry_obs[0]*-1.0, GPP_sturt_obs[0]*-1.0  ] 
gppwet_dingo = [GPP_howard_obs[1]*-1.0, GPP_litch_obs[1]*-1.0, GPP_adelaide_obs[1]*-1.0, GPP_daly_obs[1]*-1.0, GPP_dry_obs[1]*-1.0, GPP_sturt_obs[1]*-1.0  ] 
gppdry_dingo = [GPP_howard_obs[2]*-1.0, GPP_litch_obs[2]*-1.0, GPP_adelaide_obs[2]*-1.0,GPP_daly_obs[2]*-1.0, GPP_dry_obs[2]*-1.0, GPP_sturt_obs[2]*-1.0  ] 
gppwet2dry_dingo = [GPP_howard_obs[4]*-1.0, GPP_litch_obs[4]*-1.0, GPP_adelaide_obs[4]*-1.0,GPP_daly_obs[4]*-1.0, GPP_dry_obs[4]*-1.0, GPP_sturt_obs[4]*-1.0  ]

# %%
#mean annual fluxes for predicted cover
ma_howard = fluxpartitions("../../data/VOM_output/HowardSprings/freedrainage_cpcff1.0/sce_best/results_daily.txt", 1995, 2015, 12, 3, 5, 9 )
ma_litch = fluxpartitions("../../data/VOM_output/Litchfield/freedrainage_cpcff1.0/sce_best/results_daily.txt", 1995, 2015, 12, 3, 5, 9 )
ma_adelaide= fluxpartitions("../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.0/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )
ma_daly = fluxpartitions("../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.0/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )
ma_dry = fluxpartitions("../../data/VOM_output/DryRiver/freedrainage_cpcff1.0/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )
ma_sturt = fluxpartitions("../../data/VOM_output/SturtPlains/freedrainage_cpcff1.0/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )

# %%
#mean annual fluxes for prescribed roots
ma_howard_jmax = fluxpartitions("../../data/VOM_output/additional_analyses/fixed_jmax/HowardSprings/sce_best/results_daily.txt", 1995, 2015, 12, 3, 5, 9 )
ma_litch_jmax = fluxpartitions("../../data/VOM_output/additional_analyses/fixed_jmax/Litchfield/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )
ma_adelaide_jmax= fluxpartitions("../../data/VOM_output/additional_analyses/fixed_jmax/AdelaideRiver/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )
ma_daly_jmax = fluxpartitions("../../data/VOM_output/additional_analyses/fixed_jmax/DalyUncleared/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )
ma_dry_jmax = fluxpartitions("../../data/VOM_output/additional_analyses/fixed_jmax/DryRiver/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )
ma_sturt_jmax = fluxpartitions("../../data/VOM_output/additional_analyses/fixed_jmax/SturtPlains/sce_best/results_daily.txt",1995, 2015, 12, 3, 5, 9 )

# %%
esoil_ma = [ma_howard[0][0], ma_litch[0][0], ma_adelaide[0][0], ma_daly[0][0], ma_dry[0][0], ma_sturt[0][0]]
etmt_ma = [ma_howard[0][1], ma_litch[0][1], ma_adelaide[0][1], ma_daly[0][1], ma_dry[0][1], ma_sturt[0][1]]
etmg_ma = [ma_howard[0][2], ma_litch[0][2], ma_adelaide[0][2], ma_daly[0][2], ma_dry[0][2], ma_sturt[0][2]]
assg_ma = [ma_howard[0][3], ma_litch[0][3], ma_adelaide[0][3], ma_daly[0][3], ma_dry[0][3], ma_sturt[0][3]]
asst_ma = [ma_howard[0][4], ma_litch[0][4], ma_adelaide[0][4], ma_daly[0][4], ma_dry[0][4], ma_sturt[0][4]]

esoil_ma_jmax = [ma_howard_jmax[0][0], ma_litch_jmax[0][0], ma_adelaide_jmax[0][0], ma_daly_jmax[0][0], ma_dry_jmax[0][0], ma_sturt_jmax[0][0]]
etmt_ma_jmax = [ma_howard_jmax[0][1], ma_litch_jmax[0][1], ma_adelaide_jmax[0][1], ma_daly_jmax[0][1], ma_dry_jmax[0][1], ma_sturt_jmax[0][1]]
etmg_ma_jmax = [ma_howard_jmax[0][2], ma_litch_jmax[0][2], ma_adelaide_jmax[0][2], ma_daly_jmax[0][2], ma_dry_jmax[0][2], ma_sturt_jmax[0][2]]
assg_ma_jmax = [ma_howard_jmax[0][3], ma_litch_jmax[0][3], ma_adelaide_jmax[0][3], ma_daly_jmax[0][3], ma_dry_jmax[0][3], ma_sturt_jmax[0][3]]
asst_ma_jmax = [ma_howard_jmax[0][4], ma_litch_jmax[0][4], ma_adelaide_jmax[0][4], ma_daly_jmax[0][4], ma_dry_jmax[0][4], ma_sturt_jmax[0][4]]

#wet season partitions
esoil_wet = [ma_howard[1][0], ma_litch[1][0], ma_adelaide[1][0], ma_daly[1][0], ma_dry[1][0], ma_sturt[1][0]]
etmt_wet = [ma_howard[1][1], ma_litch[1][1], ma_adelaide[1][1], ma_daly[1][1], ma_dry[1][1], ma_sturt[1][1]]
etmg_wet = [ma_howard[1][2], ma_litch[1][2], ma_adelaide[1][2], ma_daly[1][2], ma_dry[1][2], ma_sturt[1][2]]
assg_wet = [ma_howard[1][3], ma_litch[1][3], ma_adelaide[1][3], ma_daly[1][3], ma_dry[1][3], ma_sturt[1][3]]
asst_wet = [ma_howard[1][4], ma_litch[1][4], ma_adelaide[1][4], ma_daly[1][4], ma_dry[1][4], ma_sturt[1][4]]

esoil_wet_jmax = [ma_howard_jmax[1][0], ma_litch_jmax[1][0], ma_adelaide_jmax[1][0], ma_daly_jmax[1][0], ma_dry_jmax[1][0], ma_sturt_jmax[1][0]]
etmt_wet_jmax = [ma_howard_jmax[1][1], ma_litch_jmax[1][1], ma_adelaide_jmax[1][1], ma_daly_jmax[1][1], ma_dry_jmax[1][1], ma_sturt_jmax[1][1]]
etmg_wet_jmax = [ma_howard_jmax[1][2], ma_litch_jmax[1][2], ma_adelaide_jmax[1][2], ma_daly_jmax[1][2], ma_dry_jmax[1][2], ma_sturt_jmax[1][2]]
assg_wet_jmax = [ma_howard_jmax[1][3], ma_litch_jmax[1][3], ma_adelaide_jmax[1][3], ma_daly_jmax[1][3], ma_dry_jmax[1][3], ma_sturt_jmax[1][3]]
asst_wet_jmax = [ma_howard_jmax[1][4], ma_litch_jmax[1][4], ma_adelaide_jmax[1][4], ma_daly_jmax[1][4], ma_dry_jmax[1][4], ma_sturt_jmax[1][4]]

#dry season partitions
esoil_dry = [ma_howard[2][0], ma_litch[2][0], ma_adelaide[2][0], ma_daly[2][0], ma_dry[2][0], ma_sturt[2][0]]
etmt_dry = [ma_howard[2][1], ma_litch[2][1], ma_adelaide[2][1], ma_daly[2][1], ma_dry[2][1], ma_sturt[2][1]]
etmg_dry = [ma_howard[2][2], ma_litch[2][2], ma_adelaide[2][2], ma_daly[2][2], ma_dry[2][2], ma_sturt[2][2]]
assg_dry = [ma_howard[2][3], ma_litch[2][3], ma_adelaide[2][3], ma_daly[2][3], ma_dry[2][3], ma_sturt[2][3]]
asst_dry = [ma_howard[2][4], ma_litch[2][4], ma_adelaide[2][4], ma_daly[2][4], ma_dry[2][4], ma_sturt[2][4]]

esoil_dry_jmax = [ma_howard_jmax[2][0], ma_litch_jmax[2][0], ma_adelaide_jmax[2][0], ma_daly_jmax[2][0], ma_dry_jmax[2][0], ma_sturt_jmax[2][0]]
etmt_dry_jmax = [ma_howard_jmax[2][1], ma_litch_jmax[2][1], ma_adelaide_jmax[2][1], ma_daly_jmax[2][1], ma_dry_jmax[2][1], ma_sturt_jmax[2][1]]
etmg_dry_jmax = [ma_howard_jmax[2][2], ma_litch_jmax[2][2], ma_adelaide_jmax[2][2], ma_daly_jmax[2][2], ma_dry_jmax[2][2], ma_sturt_jmax[2][2]]
assg_dry_jmax = [ma_howard_jmax[2][3], ma_litch_jmax[2][3], ma_adelaide_jmax[2][3], ma_daly_jmax[2][3], ma_dry_jmax[2][3], ma_sturt_jmax[2][3]]
asst_dry_jmax = [ma_howard_jmax[2][4], ma_litch_jmax[2][4], ma_adelaide_jmax[2][4], ma_daly_jmax[2][4], ma_dry_jmax[2][4], ma_sturt_jmax[2][4]]

#wet2dry season partitions
esoil_wet2dry  = [ma_howard[4][0], ma_litch[4][0], ma_adelaide[4][0], ma_daly[4][0], ma_dry[4][0], ma_sturt[4][0]]
etmt_wet2dry  = [ma_howard[4][1], ma_litch[4][1], ma_adelaide[4][1], ma_daly[4][1], ma_dry[4][1], ma_sturt[4][1]]
etmg_wet2dry  = [ma_howard[4][2], ma_litch[4][2], ma_adelaide[4][2], ma_daly[4][2], ma_dry[4][2], ma_sturt[4][2]]
assg_wet2dry  = [ma_howard[4][3], ma_litch[4][3], ma_adelaide[4][3], ma_daly[4][3], ma_dry[4][3], ma_sturt[4][3]]
asst_wet2dry  = [ma_howard[4][4], ma_litch[4][4], ma_adelaide[4][4], ma_daly[4][4], ma_dry[4][4], ma_sturt[4][4]]

esoil_wet2dry_jmax = [ma_howard_jmax[4][0], ma_litch_jmax[4][0], ma_adelaide_jmax[4][0], ma_daly_jmax[4][0], ma_dry_jmax[4][0], ma_sturt_jmax[2][0]]
etmt_wet2dry_jmax = [ma_howard_jmax[4][1], ma_litch_jmax[4][1], ma_adelaide_jmax[4][1], ma_daly_jmax[4][1], ma_dry_jmax[4][1], ma_sturt_jmax[2][1]]
etmg_wet2dry_jmax = [ma_howard_jmax[4][2], ma_litch_jmax[4][2], ma_adelaide_jmax[4][2], ma_daly_jmax[4][2], ma_dry_jmax[4][2], ma_sturt_jmax[2][2]]
assg_wet2dry_jmax = [ma_howard_jmax[4][3], ma_litch_jmax[4][3], ma_adelaide_jmax[4][3], ma_daly_jmax[4][3], ma_dry_jmax[4][3], ma_sturt_jmax[2][3]]
asst_wet2dry_jmax = [ma_howard_jmax[4][4], ma_litch_jmax[4][4], ma_adelaide_jmax[4][4], ma_daly_jmax[4][4], ma_dry_jmax[4][4], ma_sturt_jmax[2][4]]

# %%
ind = np.arange(0,24, 4)
ind2 = ind + 1
ind3 = ind2 + 1



fig, axes   = plt.subplots(nrows=4, ncols=2, figsize=(15, 20), sharex = True )
ax = axes.flat

#################################################
p1 = ax[0].bar(ind, esoil_ma, color="green")
p2 = ax[0].bar(ind, etmt_ma, bottom=esoil_ma, color="orange")
p3 = ax[0].bar(ind, etmg_ma, bottom=np.add(etmt_ma,esoil_ma),color="blue")

p4 = ax[0].bar(ind2, esoil_ma_jmax, color="green")
p5 = ax[0].bar(ind2, etmt_ma_jmax, bottom=esoil_ma_jmax, color="orange")
p6 = ax[0].bar(ind2, etmg_ma_jmax, bottom=np.add(etmt_ma_jmax,esoil_ma_jmax), color="blue")

p7 = ax[0].bar(ind3, etot_dingo, color="grey")


ax[0].set_ylabel(r'Evaporation [mm/year]', fontsize=18)
ax[0].set_xticks(ind+0.5) 
ax[0].tick_params(axis="x", pad = 50)
ax[0].set_xticklabels( ('Howard Springs', 'Litchfield', 'Adelaide River', 'Daly Uncleared', 'Dry River', "Sturt Plains"),rotation=90, fontsize=18)
ax[0].legend((p1[0], p2[0], p3[0]), ('Esoil', 'Etmt', 'Etmg'))

ax[0].text(-0.15, 1.05, "a)", transform=ax[0].transAxes, 
            size=18)

for loc in ind:
    ax[0].text(loc, -40, "Predicted Jmax", size=8, rotation=90, horizontalalignment='center')
    
for loc in ind2:
    ax[0].text(loc, -40, "Fixed Jmax", size=8, rotation=90, horizontalalignment='center')

for loc in ind3:
    ax[0].text(loc, -40, "Observed", size=8, rotation=90, horizontalalignment='center')

    
###################################################

p1 = ax[1].bar(ind, assg_ma, color="red")
p2 = ax[1].bar(ind, asst_ma, bottom=assg_ma, color="purple")

p4 = ax[1].bar(ind2, assg_ma_jmax, color="red")
p5 = ax[1].bar(ind2, asst_ma_jmax, bottom=assg_ma_jmax, color="purple")

p6 = ax[1].bar(ind3, gpptot_dingo, color="grey")

for loc in ind:
    ax[1].text(loc, -5, "Predicted Jmax", size=8, rotation=90, horizontalalignment='center')
    
for loc in ind2:
    ax[1].text(loc, -5, "Fixed Jmax", size=8, rotation=90, horizontalalignment='center')

for loc in ind3:
    ax[1].text(loc, -5, "Observed", size=8, rotation=90, horizontalalignment='center')
     
    
ax[1].set_ylabel(r'Assimilation [mol/m$^2$/year]', fontsize=18)
ax[1].set_xticks(ind+0.5) 
ax[1].tick_params(axis="x",pad = 50)
ax[1].set_xticklabels( ('Howard Springs', 'Litchfield', 'Adelaide River', 'Daly Uncleared', 'Dry River', "Sturt Plains"),rotation=90, fontsize=18 )
ax[1].legend((p1[0], p2[0]), ('Assg', 'Asst'))

ax[1].text(-0.15, 1.05, "b)", transform=ax[1].transAxes, size=18)

#########################################################
#wet season
p1 = ax[2].bar(ind, esoil_wet, color="green")
p2 = ax[2].bar(ind, etmt_wet, bottom=esoil_wet, color="orange")
p3 = ax[2].bar(ind, etmg_wet, bottom=np.add(etmt_wet,esoil_wet),color="blue")

p4 = ax[2].bar(ind2, esoil_wet_jmax, color="green")
p5 = ax[2].bar(ind2, etmt_wet_jmax, bottom=esoil_wet_jmax, color="orange")
p6 = ax[2].bar(ind2, etmg_wet_jmax, bottom=np.add(etmt_wet_jmax,esoil_wet_jmax), color="blue")

p7 = ax[2].bar(ind3, ewet_dingo, color="grey")


ax[2].set_ylabel(r'Evaporation [mm/year]', fontsize=18)
ax[2].set_xticks(ind+0.5) 
ax[2].tick_params(axis="x", pad = 50)
ax[2].set_xticklabels( ('Howard Springs', 'Litchfield', 'Adelaide River', 'Daly Uncleared', 'Dry River', "Sturt Plains"),rotation=90, fontsize=18)
ax[2].legend((p1[0], p2[0], p3[0]), ('Esoil', 'Etmt', 'Etmg'))

ax[2].text(-0.15, 1.05, "c)", transform=ax[2].transAxes, 
            size=18)

for loc in ind:
    ax[2].text(loc, -20, "Predicted Jmax", size=8, rotation=90, horizontalalignment='center')
    
for loc in ind2:
    ax[2].text(loc, -20, "Fixed Jmax", size=8, rotation=90, horizontalalignment='center')

for loc in ind3:
    ax[2].text(loc, -20, "Observed", size=8, rotation=90, horizontalalignment='center')

###################################################
#wet season assimilation
p1 = ax[3].bar(ind, assg_wet, color="red")
p2 = ax[3].bar(ind, asst_wet, bottom=assg_wet, color="purple")

p4 = ax[3].bar(ind2, assg_wet_jmax, color="red")
p5 = ax[3].bar(ind2, asst_wet_jmax, bottom=assg_wet_jmax, color="purple")

p6 = ax[3].bar(ind3, gppwet_dingo, color="grey")

for loc in ind:
    ax[3].text(loc, -3, "Predicted Jmax", size=8, rotation=90, horizontalalignment='center')
    
for loc in ind2:
    ax[3].text(loc, -3, "Fixed Jmax", size=8, rotation=90, horizontalalignment='center')

for loc in ind3:
    ax[3].text(loc, -3, "Observed", size=8, rotation=90, horizontalalignment='center')
     
    
ax[3].set_ylabel(r'Assimilation [mol/m$^2$/year]', fontsize=18)
ax[3].set_xticks(ind+0.5) 
ax[3].tick_params(axis="x",pad = 50)
ax[3].set_xticklabels( ('Howard Springs', 'Litchfield', 'Adelaide River', 'Daly Uncleared', 'Dry River', "Sturt Plains"),rotation=90, fontsize=18 )
ax[3].legend((p1[0], p2[0]), ('Assg', 'Asst'))

ax[3].text(-0.15, 1.05, "d)", transform=ax[3].transAxes, size=18)


#########################################################
#dry season evaporation
p1 = ax[4].bar(ind, esoil_dry, color="green")
p2 = ax[4].bar(ind, etmt_dry, bottom=esoil_dry, color="orange")
p3 = ax[4].bar(ind, etmg_dry, bottom=np.add(etmt_dry,esoil_dry),color="blue")

p4 = ax[4].bar(ind2, esoil_dry_jmax, color="green")
p5 = ax[4].bar(ind2, etmt_dry_jmax, bottom=esoil_dry_jmax, color="orange")
p6 = ax[4].bar(ind2, etmg_dry_jmax, bottom=np.add(etmt_dry_jmax,esoil_dry_jmax), color="blue")

p7 = ax[4].bar(ind3, edry_dingo, color="grey")


ax[4].set_ylabel(r'Evaporation [mm/year]', fontsize=18)
ax[4].set_xticks(ind+0.5) 
ax[4].tick_params(axis="x", pad = 50)
#ax[4].set_xticklabels( ('Howard Springs', 'Litchfield', 'Adelaide River', 'Daly Uncleared', 'Dry River', "Sturt Plains"),rotation=90, fontsize=18)
ax[4].legend((p1[0], p2[0], p3[0]), ('Esoil', 'Etmt', 'Etmg'))

ax[4].text(-0.15, 1.05, "e)", transform=ax[4].transAxes, 
            size=18)

for loc in ind:
    ax[4].text(loc, -10, "Predicted Jmax", size=8, rotation=90, horizontalalignment='center')
    
for loc in ind2:
    ax[4].text(loc, -10, "Fixed Jmax", size=8, rotation=90, horizontalalignment='center')

for loc in ind3:
    ax[4].text(loc, -10, "Observed", size=8, rotation=90, horizontalalignment='center')


###################################################
#dry season assimilation
p1 = ax[5].bar(ind, assg_dry, color="red")
p2 = ax[5].bar(ind, asst_dry, bottom=assg_dry, color="purple")

p4 = ax[5].bar(ind2, assg_dry_jmax, color="red")
p5 = ax[5].bar(ind2, asst_dry_jmax, bottom=assg_dry_jmax, color="purple")

p6 = ax[5].bar(ind3, gppdry_dingo, color="grey")

for loc in ind:
    ax[5].text(loc, -2, "Predicted Jmax", size=8, rotation=90, horizontalalignment='center')
    
for loc in ind2:
    ax[5].text(loc, -2, "Fixed Jmax", size=8, rotation=90, horizontalalignment='center')

for loc in ind3:
    ax[5].text(loc, -2, "Observed", size=8, rotation=90, horizontalalignment='center')
     
    
ax[5].set_ylabel(r'Assimilation [mol/m$^2$/year]', fontsize=18)
ax[5].set_xticks(ind+0.5) 
ax[5].tick_params(axis="x",pad = 50)
#ax[5].set_xticklabels( ('Howard Springs', 'Litchfield', 'Adelaide River', 'Daly Uncleared', 'Dry River', "Sturt Plains"),rotation=90, fontsize=18 )
ax[5].legend((p1[0], p2[0]), ('Assg', 'Asst'))

ax[5].text(-0.15, 1.05, "f)", transform=ax[5].transAxes, size=18)




#########################################################
#dry season evaporation
p1 = ax[6].bar(ind, esoil_wet2dry, color="green")
p2 = ax[6].bar(ind, etmt_wet2dry, bottom=esoil_wet2dry, color="orange")
p3 = ax[6].bar(ind, etmg_wet2dry, bottom=np.add(etmt_wet2dry,esoil_wet2dry),color="blue")

p4 = ax[6].bar(ind2, esoil_wet2dry_jmax, color="green")
p5 = ax[6].bar(ind2, etmt_wet2dry_jmax, bottom=esoil_wet2dry_jmax, color="orange")
p6 = ax[6].bar(ind2, etmg_wet2dry_jmax, bottom=np.add(etmt_wet2dry_jmax,esoil_wet2dry_jmax), color="blue")

p7 = ax[6].bar(ind3, ewet2dry_dingo, color="grey")


ax[6].set_ylabel(r'Evaporation [mm/year]', fontsize=18)
ax[6].set_xticks(ind+0.5) 
ax[6].tick_params(axis="x", pad = 50)
ax[6].set_xticklabels( ('Howard Springs', 'Litchfield', 'Adelaide River', 'Daly Uncleared', 'Dry River', "Sturt Plains"),rotation=90, fontsize=18)
ax[6].legend((p1[0], p2[0], p3[0]), ('Esoil', 'Etmt', 'Etmg'))

ax[6].text(-0.15, 1.05, "g)", transform=ax[6].transAxes, 
            size=18)

for loc in ind:
    ax[6].text(loc, -5, "Predicted Jmax", size=8, rotation=90, horizontalalignment='center')
    
for loc in ind2:
    ax[6].text(loc, -5, "Fixed Jmax", size=8, rotation=90, horizontalalignment='center')

for loc in ind3:
    ax[6].text(loc, -5, "Observed", size=8, rotation=90, horizontalalignment='center')


###################################################
#wet2dry season assimilation
p1 = ax[7].bar(ind, assg_wet2dry, color="red")
p2 = ax[7].bar(ind, asst_wet2dry, bottom=assg_wet2dry, color="purple")

p4 = ax[7].bar(ind2, assg_wet2dry_jmax, color="red")
p5 = ax[7].bar(ind2, asst_wet2dry_jmax, bottom=assg_wet2dry_jmax, color="purple")

p6 = ax[7].bar(ind3, gppwet2dry_dingo, color="grey")

for loc in ind:
    ax[7].text(loc, -1, "Predicted Jmax", size=8, rotation=90, horizontalalignment='center')
    
for loc in ind2:
    ax[7].text(loc, -1, "Fixed Jmax", size=8, rotation=90, horizontalalignment='center')

for loc in ind3:
    ax[7].text(loc, -1, "Observed", size=8, rotation=90, horizontalalignment='center')
     
    
ax[7].set_ylabel(r'Assimilation [mol/m$^2$/year]', fontsize=18)
ax[7].set_xticks(ind+0.5) 
ax[7].tick_params(axis="x",pad = 50)
ax[7].set_xticklabels( ('Howard Springs', 'Litchfield', 'Adelaide River', 'Daly Uncleared', 'Dry River', "Sturt Plains"),rotation=90, fontsize=18 )
ax[7].legend((p1[0], p2[0]), ('Assg', 'Asst'))

ax[7].text(-0.15, 1.05, "h)", transform=ax[7].transAxes, size=18)


plt.show()

# %% [markdown]
# **Figure S12.11.** Partitioning of the fluxes for a) total evaporation and b) total assimilation, c) wet season evaporation, d) wet season assimilation, e) dry season evaporation, f) dry season assimilation, g) evaporation during the transition from the wet to the dry season, and h) assimilation during the transition from the wet to the dry season. Flux tower observations are shown in gray.

# %% [markdown]
# ## Parameters

# %%
#plot parameters

basin = ["HowardSprings", "AdelaideRiver", "Litchfield", "DalyUncleared", "DryRiver", "SturtPlains"]
site_names = ["Howard Springs", "Adelaide River", "Litchfield", "Daly Uncleared", "Dry River", "Sturt Plains" ]



fig=plt.figure(figsize=(16, 5), dpi= 80, facecolor='w', edgecolor='k')
#fig, ((ax0, ax1, ax2, ax3, ax4, ax5, ax6) )  = plt.subplots(nrows=1, ncols=7, figsize=(16, 5)) 
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 15)) 
ax = axes.flat


for ibasin in  np.array([0, 1, 2, 3, 4, 5]):  
    
    #loop over files and load
    try:
        params = np.loadtxt("../../work/" + 
             basin[ibasin] + "/freedrainage_cpcff1.0/best/input/pars.txt") #mm/d
    except OSError:
        print("../../work/" + 
             basin[ibasin] + "/freedrainage_cpcff1.0/best/input/pars.txt") #mm/d
  
    try:
        params_pc = np.loadtxt("../../data/VOM_output/additional_analyses/fixed_jmax/" + 
             basin[ibasin] + "/sce_best/pars.txt") #mm/d
    except OSError:
        params_pc = np.loadtxt("../../work/additional_analyses/fixed_jmax/" + 
             basin[ibasin] + "/best/input/pars.txt") #mm/d
        
    #for irun in range(0,4):
    if(ibasin == 0):
        ax[0].plot([ibasin], params[0], "r*" , label = "predicted Jmax" ) 
        ax[0].plot([ibasin], params_pc[0], "b*" , label =  "fixed Jmax" ) 
    else:
        ax[0].plot([ibasin], params[0], "r*" ) 
        ax[0].plot([ibasin], params_pc[0], "b*" )         
        
    ax[1].plot([ibasin], params[1], "r*" , label = "VOM" ) 
    ax[1].plot([ibasin], params_pc[1], "b*" , label = "VOM pres. roots" ) 

    ax[2].plot([ibasin], params[2], "r*" , label = "VOM" ) 
    ax[2].plot([ibasin], params_pc[2], "b*" , label = "VOM pres. roots" ) 

    ax[3].plot([ibasin], params[3], "r*" , label = "VOM" ) 
    ax[3].plot([ibasin], params_pc[3], "b*" , label = "VOM pres. roots" ) 

    ax[4].plot([ibasin], params[4], "r*" , label = "VOM" ) 
    ax[4].plot([ibasin], params_pc[4], "b*" , label = "VOM pres. roots" ) 

    ax[5].plot([ibasin], params[5], "r*" , label = "VOM" ) 
    ax[5].plot([ibasin], params_pc[5], "b*" , label = "VOM pres. roots" ) 

    ax[6].plot([ibasin], params[6], "r*" , label = "VOM" ) 
    ax[6].plot([ibasin], params_pc[6], "b*" , label = "VOM pres. roots" ) 
    
    ax[7].plot([ibasin], params[7], "r*" , label = "VOM" ) 
    ax[7].plot([ibasin], params_pc[7], "b*" , label = "VOM pres. roots" ) 


#ax0.set_ylim([0,10])  
ax[0].set_xlim( -1, 6  )     
ax[0].set_xticks( [0,1,2,3,4,5] )  
ax[0].set_xticklabels( site_names, rotation=90 )  
ax[0].set_ylabel(r"$c_{\lambda f,s}$ $[mol/mol/m ]$", size=16 )  
ax[0].grid(color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax[0].text(0.01, 0.9, "a)", ha='left', va='center', transform=ax[0].transAxes, fontsize=20)
ax[0].legend()

#ax1.set_ylim([0,10])  
ax[1].set_xlim( -1, 6  )     
ax[1].set_xticks( [0,1,2,3,4,5] )  
ax[1].set_xticklabels( site_names, rotation=90 )  
ax[1].set_ylabel(r"$c_{\lambda e,s}$  $[-]$", size=16 )  
ax[1].grid(color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax[1].text(0.01, 0.9, "b)", ha='left', va='center', transform=ax[1].transAxes, fontsize=20)

#ax2.set_ylim([0,1]) 
ax[2].set_xlim( -1, 6  ) 
ax[2].set_xticks( [0,1,2,3,4,5] )  
ax[2].set_xticklabels( site_names, rotation=90 )  
ax[2].set_ylabel(r"$c_{\lambda f,p}$  $[mol/mol/m ]$", size=16 )
ax[2].grid(color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax[2].text(0.01, 0.9, "c)", ha='left', va='center', transform=ax[2].transAxes, fontsize=20)

#ax0.set_ylim([0,1])  
ax[3].set_xlim( -1, 6  )   
ax[3].set_xticks( [0,1,2,3,4,5] )  
ax[3].set_xticklabels( site_names, rotation=90 )  
ax[3].set_ylabel(r"$c_{\lambda e,p}$ $[-]$", size=16 ) 
ax[3].grid(color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax[3].text(0.01, 0.9, "d)", ha='left', va='center', transform=ax[3].transAxes, fontsize=20)

#ax1.set_ylim([0,10])  
ax[4].set_xlim( -1, 6  )     
ax[4].set_xticks( [0,1,2,3,4,5] )  
ax[4].set_xticklabels( site_names, rotation=90 )  
ax[4].set_ylabel(r"$M_A$  $[-]$", size=16 )  
ax[4].grid(color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax[4].text(0.01, 0.9, "e)", ha='left', va='center', transform=ax[4].transAxes, fontsize=20)

#ax2.set_ylim([0,1]) 
ax[5].set_xlim( -1, 6  ) 
ax[5].set_xticks( [0,1,2,3,4,5] )  
ax[5].set_xticklabels( site_names, rotation=90 )  
ax[5].set_ylabel(r"$y_{r,p}$  $[m]$", size=16 )  
ax[5].grid(color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax[5].text(0.01, 0.9, "f)", ha='left', va='center', transform=ax[5].transAxes, fontsize=20)

ax[6].set_xlim( -1, 6  ) 
ax[6].set_xticks( [0,1,2,3,4,5] )  
ax[6].set_xticklabels( site_names, rotation=90 )  
ax[6].set_ylabel("mdstore [-]", size=16 )  
ax[6].grid(color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax[6].text(0.01, 0.9, "g)", ha='left', va='center', transform=ax[6].transAxes, fontsize=20)

ax[7].set_xlim( -1, 6  ) 
ax[7].set_xticks( [0,1,2,3,4,5] )  
ax[7].set_xticklabels( site_names, rotation=90 )  
ax[7].set_ylabel(r"$y_{r,s}$ $[m]$", size=16 )  
ax[7].grid(color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax[7].text(0.01, 0.9, "h)", ha='left', va='center', transform=ax[7].transAxes, fontsize=20)


plt.figtext( x=0, y=1.05, s="Optimized parameters", weight='bold', fontsize = 18)
plt.tight_layout()
    
plt.show()

# %% [markdown]
# **Figure S12.12.** Optimal vegetation parameters for fixed Jmax (blue) and predicted Jmax (red) , for a) and b) the two parameters $c_{\lambda f,s}$ and  $c_{\lambda e,s}$ effecting the water use for perennial vegetation, c) and d) the two parameters $c_{\lambda f,p}$ and $c_{\lambda e,p}$ effecting the water use for seasonal vegetation, e) vegetation cover of the perennial vegetation $M_{A,p}$, f) the rooting depth for the perennial vegetation $y_{r,p}$ and g) the plant water storage (fixed) and h) the rooting depth for the seasonal vegetation $y_{r,s}$.

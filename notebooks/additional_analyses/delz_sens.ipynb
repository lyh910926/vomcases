# %% [markdown]
# # Sensitivity of soil layer thickness

# %% [markdown]
# ## Soil moisture profiles

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta, date
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from scipy.misc import imread
import matplotlib.cbook as cbook

# %%
#HowardSprings
# %run ../../src_py/plot_smprofile.py  \
-i ../../data/VOM_output/additional_analyses/sens_delz/HS_0.10/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.15/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.20/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.25/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.30/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.35/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.40/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.45/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.50/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.55/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.65/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.70/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.75/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.80/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.85/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.90/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.95/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_1.00/sce_best/su_hourly.txt \
-d 0.10 0.15 0.20 0.25 0.30 0.35 0.40 0.45 0.50 0.55 0.60 0.65 0.70 0.75 0.80 0.85 0.90 0.95 1.00 \
-cz 48.40 -nd 3650 --ylabel "Depth [m]" --xlabel "Su [-]" --cbar_min 0.10 --cbar_max 1.00 \
--cblabel "Layer thickness [m]" --plot_cbar True
# Out:
# Script finished

# %% [markdown]
# **Figure S2.1.** Average soil moisture profiles for different soil layer thicknesses at Howard Springs. Generally, results remain rather similar for the upper layers, especially for the lower values of layer thickness. Jumps in the lowest layers can be observed, starting from a depth of 40m.

# %% [markdown]
# ## Differences in profiles

# %%
#HowardSprings
# %run ../../src_py/plot_smdifferences.py  \
-i ../../data/VOM_output/additional_analyses/sens_delz/HS_0.10/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.15/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.20/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.25/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.30/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.35/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.40/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.45/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.50/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.55/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.60/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.65/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.70/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.75/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.80/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.85/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.90/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.95/sce_best/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_1.00/sce_best/su_hourly.txt \
-d 0.10 0.15 0.20 0.25 0.30 0.35 0.40 0.45 0.50 0.55 0.60 0.65 0.70 0.75 0.80 0.85 0.90 0.95 1.00 \
-cz 48.4 -nd 3650 --ylabel "dSu [-]" --xlabel "Soil layer thickness [m]" --ylim -0.5 0.5 --figsize 14 5
# Out:
# Script finished

# %% [markdown]
# **Figure S2.2.** Differences at different depths (5%, 25%, 50%, 75% and 95% depth) between the average soil moisture for a specific soil layer thickness and the subsequent soil layer thickness (e.g. the difference between 0.25m and 0.30m soil layer thickness at 50% depth) at Howard Springs. From soil layers smaller then 0.5 m, the differences at the difference depths become very small, and are negligble from 0.25m.

# %% [markdown]
# ## Relative errors mean annual fluxes

# %%
vals = np.arange(0.10,1.05, 0.05)
labels = map("{:.2f}".format, vals)
labels = list(labels)

fig=plt.figure(figsize=(16, 5), dpi= 80, facecolor='w', edgecolor='k')
fig, ax   = plt.subplots(nrows=1, ncols=1, figsize=(24, 8), sharex=True, sharey=True)   

i = 0
skipped = 0


loc = 1
#loop over all values 
for label in labels:   

    try:
        ebest_stats = np.genfromtxt("../../data/VOM_output/additional_analyses/sens_delz/HS_" + 
          label + "/sce_stats_best/evap_beststats.txt") #mm/d

        assbest_stats = np.genfromtxt("../../data/VOM_output/additional_analyses/sens_delz/HS_" + 
          label + "/sce_stats_best/ass_beststats.txt") #mm/d       

        if(i == 0):
            box1 = ax.plot(vals[i], ebest_stats[1]*100, '*r', markersize=15, label="evaporation" ) 
            ax.plot(vals[i], assbest_stats[1]*100, '*b', markersize=15, label="assimilation" ) 
        else:
            box1 = ax.plot(vals[i], ebest_stats[1]*100, '*r', markersize=15 ) 
            ax.plot(vals[i], assbest_stats[1]*100, '*b', markersize=15 ) 

    except IOError:
        skipped = skipped + 1 
        print("../../data/VOM_output/additional_analyses/sens_delz/HS_" + 
          label + "/sce_stats_best/ass_beststats.txt')")
    i = i + 1


ax.set_ylim([-1.5, 1.5])    
ax.set_xlim([0, 1])    
ax.grid(b=True, which='both', color='grey', axis="both", linestyle='--')

ax.set_xticks( np.arange(0,1.25, 0.25)  )  
ax.set_xticks( np.arange(0,1.25, 0.05), minor=True )  

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(25)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(25)
    
plt.xlabel("Soil layer thickness (m)", size = 25, labelpad=40)
plt.ylabel('Mean Annual Rel. Err. (%)', size = 25, labelpad=40)

plt.legend(prop={'size': 15})
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure S2.3.** The errors between observations from the fluxtowers and modelled fluxes of evaporation (red) and assimilation (blue) at Howard Springs. The errors are generally in the same order of magnitude, only for a value 0.90m a large error is observed, also due to numerical instabilities.

# %% [markdown]
# ## Timeseries of evaporation

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/additional_analyses/sens_delz/HS_0.10/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.15/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.20/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.25/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.30/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.35/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.40/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.45/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.50/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.55/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.60/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.65/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.70/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.75/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.80/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.85/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.90/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.95/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_1.00/sce_best/results_daily.txt \
-v evaptot -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--obs ../../data/DINGO/Ea_howard.txt --mf 1000 --ylabel "Etot [mm/d]" --plot_cbar True \
--cbar_max 1.0 --cbar_min 0.10 --cblabel "delz (m)" --labels VOM VOM2 \
--title "HowardSprings" --legend True

# %% [markdown]
# **Figure 2.4.** The timeseries of total evaporation for Howard Springs with observations in blue and the results for different soil layers thicknesses colored from light yellow to darkred. The values generally still plot close together, but higher values seem to be closer to the observations.

# %% [markdown]
# ## Timeseries of assimilation

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/additional_analyses/sens_delz/HS_0.10/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.15/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.20/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.25/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.30/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.35/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.40/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.45/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.50/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.55/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.60/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.65/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.70/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.75/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.80/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.85/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.95/sce_best/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_1.00/sce_best/results_daily.txt \
-v asstot -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--obs ../../data/DINGO/GPPdaily_howard.txt --mf_obs -1 --ylabel "$CO_2-uptake$ $[mol/m^2/d]$" \
--plot_cbar True --cbar_max 1.0 --cbar_min 0.10 --cblabel "delz (m)" --labels VOM VOM2 \
--title "HowardSprings" --legend True

# %% [markdown]
# The timeseries of total assimilation do not show large difference between different soil layer thicknesses (colored from light yellow to darkred) with the observations (blue).

# %% [markdown]
# ## Parameter values

# %%
#plot parameters
delz = np.arange(0.05,1.05,0.05)
delz_str = [ "0.05", "0.10", "0.15", "0.20", "0.25", "0.35", "0.40", "0.45", "0.50", "0.55", "0.60", "0.65", "0.70", "0.75", "0.80", "0.85", "0.95", "1.00"]

fig=plt.figure(figsize=(16, 5), dpi= 80, facecolor='w', edgecolor='k')
fig, ax = plt.subplots(nrows=8, ncols=1, figsize=(12, 25)) 


icount = 0
for i_delz in  delz_str:  
    
    params_tmp = np.loadtxt("../../data/VOM_output/additional_analyses/sens_delz/HS_" + 
             i_delz + "/sce_best/pars.txt")

    for i in range(0,8):
        ax[i].plot(delz[icount], params_tmp[i], 'r*' , markersize=10)     
    icount = icount + 1 
    
ax[0].set_ylabel("lambdagf [mol/mol/m ]", size=12 )  
ax[0].set_ylim( 0, 10000  )    

ax[1].set_ylabel("wsgexp [-]", size=12 )  
ax[1].set_ylim( -3, 1  )    

ax[2].set_ylabel("lambdatf [mol/mol/m ]", size=12 )
ax[2].set_ylim( 0, 10000  )    

ax[3].set_ylabel("wstexp [-]", size=12 ) 
ax[3].set_ylim( -3, 1  )    

ax[4].set_ylabel("cai [-]", size=12 )  
ax[4].set_ylim( 0, 1  )    

ax[5].set_ylabel("rtdepth trees [m]", size=12 )  
ax[5].set_ylim( 1, 9  )    

ax[6].set_ylabel("mdstore [-]", size=12 )  
ax[6].set_ylim( 0, 120  )    

ax[7].set_ylabel("rgdepth [m]", size=12 )  
ax[7].set_ylim( 0.05, 2  )    

plt.tight_layout()
    
plt.show()

# %% [markdown]
# # Fixed parameters for different soil thickness
# The optimal parameters from the SCE-runs for 0.5m depth were used to run the VOM also for other soil-layers. Theoretically, the results should remain exactly the same, but this will not happen due to the different soil discretization.

# %% [markdown]
# ## Soil moisture profiles

# %%
#HowardSprings
# %run ../../src_py/plot_smprofile.py  \
-i ../../data/VOM_output/additional_analyses/sens_delz/HS_0.05/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.10/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.15/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.20/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.25/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.35/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.40/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.45/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.50/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.55/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.65/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.70/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.75/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.80/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.85/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.95/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_1.00/sce_best0.50/su_hourly.txt \
-d 0.05 0.10 0.15 0.20 0.25 0.35 0.40 0.45 0.50 0.55 0.60 0.65 0.70 0.75 0.80 0.85 0.95 1.00 \
-cz 36.5 -nd 3650 --ylabel "Depth [m]" --xlabel "Su [-]" --cbar_min 0.05 --cbar_max 1.00 \
--cblabel "delz [m]" --plot_cbar True
# Out:
# No handles with labels found to put in legend.
# Script finished

# %% [markdown]
# The soil moisture profiles look really similar to the profiles that are obtained for the optimized VOM-runs, only some small differences can be observed. This indicates that most of the variability here is caused by the different soil discretization, and only for a minor part by the different SCE-outcomes.

# %% [markdown]
# ## Differences in profiles

# %%
#HowardSprings
# %run ../../src_py/plot_smdifferences.py  \
-i ../../data/VOM_output/additional_analyses/sens_delz/HS_0.05/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.10/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.15/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.20/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.25/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.35/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.40/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.45/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.50/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.55/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.60/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.65/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.70/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.75/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.80/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.85/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.95/sce_best0.50/su_hourly.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_1.00/sce_best0.50/su_hourly.txt \
-d 0.05 0.10 0.15 0.20 0.25 0.35 0.40 0.45 0.50 0.55 0.60 0.65 0.70 0.75 0.80 0.85 0.95 1.00 \
-cz 36.5 -nd 3650 --ylabel "dSu [-]" --xlabel "Soil layer thickness [m]" --ylim -0.5 0.5 --figsize 14 6
# Out:
# Script finished

# %% [markdown]
# This plot also shows many similarities with the plot for the optimized VOM-results. Also here, deviations become larger for soil layer thicknesses of 0.6m.

# %% [markdown]
# ## Timeseries of evaporation

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/additional_analyses/sens_delz/HS_0.05/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.10/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.15/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.20/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.25/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.30/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.35/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.40/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.45/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.50/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.55/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.60/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.65/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.70/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.75/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.80/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.85/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.90/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.95/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_1.00/sce_best0.50/results_daily.txt \
-v evaptot -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--obs ../../data/DINGO/Ea_howard.txt --mf 1000 --ylabel "Etot [mm/d]" --plot_cbar True \
--cbar_max 1.0 --cbar_min 0.05 --cblabel "delz (m)" --labels VOM VOM2 \
--title "HowardSprings"

# %% [markdown]
# The modelled evaporation shows generally less variability compared to the runs that were optimized.

# %% [markdown]
# ## Timeseries of assimilation

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/additional_analyses/sens_delz/HS_0.05/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.10/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.15/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.20/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.25/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.30/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.35/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.40/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.45/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.50/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.55/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.60/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.65/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.70/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.75/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.80/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.85/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.90/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_0.95/sce_best0.50/results_daily.txt \
../../data/VOM_output/additional_analyses/sens_delz/HS_1.00/sce_best0.50/results_daily.txt \-v asstot -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--obs ../../data/DINGO/GPPdaily_howard.txt --mf_obs -1 --ylabel "CO2 [mol/m2/d]" \
--plot_cbar True --cbar_max 1.0 --cbar_min 0.05 --cblabel "delz (m)" --labels VOM VOM2 \
--title "HowardSprings"

# %% [markdown]
# Also here, the modelled assimilation shows less variability compared to optimized model runs.

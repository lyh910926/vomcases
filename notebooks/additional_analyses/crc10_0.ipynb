# %%
# %run ../../src_py/plot_et_ass_pc.py \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff10.0//sce_best/results_daily.txt \
-ys 2006 -ye 2010 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--assobs ../../data/DINGO/GPPdaily_howard.txt --assobs_qc ../../data/DINGO_QC/FcQ_howard.txt \
--eobs_qc ../../data/DINGO_QC/FeQ_howard.txt --eobs ../../data/DINGO/Ea_howard.txt \
--pcobs ../../data/fPAR/fpar_howard_v5.txt \
--pcobsdates ../../data/fPAR/dates_v5 --labels VOM  --legend True \
--xloc_title -0.05 --yloc_title 1.10 --size_title 24 --moving_average 7 --palette RdYlGn \
--cblabel "$c_{rv}$ ($\mu mol m^3 s^{-1})$"

# %%
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff10.0/sce_best/results_daily.txt \
-v ncp_g -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn --moving_average 7 \
--ylabel "NCP$_{grasses}$(mol m$^{-}$$^{2}$ d$^{-}$$^{1}$)" \
--labels "c_rv = 10" "prescribed cover" "prescribed cover - mean monthly"  --title "a)" --legend True  \
--colors red black gray --moving_average 7 \
--obs ../../data/DINGO/GPPdaily_howard.txt --mf_obs -1 \
--figsize 18 4
# Out:
# /home/remko/.local/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff10.0/sce_best/results_daily.txt \
-v cpccg_d -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn --moving_average 7 \
--ylabel "Costs water transport (mol m$^{-}$$^{2}$ d$^{-}$$^{1}$)" \
--labels "c_rv = 10" "prescribed cover" "prescribed cover - mean monthly"  --title "" --legend True  \
--colors red black gray --moving_average 7 \
--obs ../../data/DINGO/GPPdaily_howard.txt --mf_obs -1 --mf 86400 \
--figsize 18 4

# %%
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff10.0/sce_best/results_daily.txt \
-v cpccg_d -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn --moving_average 7 \
--ylabel "Costs water transport (mol m$^{-}$$^{2}$ d$^{-}$$^{1}$)" \
--labels "c_rv = 10" "prescribed cover" "prescribed cover - mean monthly"  --title "" --legend True  \
--colors red black gray --moving_average 7 \
--figsize 18 4

# %%
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff10.0/sce_best/results_daily.txt \
-v esoil -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn --moving_average 7 \
--ylabel "Esoil (mm/d)" \
--labels "c_rv = 10" "prescribed cover" "prescribed cover - mean monthly"  --title "a)" --legend True  \
--colors red black gray --moving_average 7 --mf 1000\
--figsize 18 4

# %%
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff10.0/sce_best/results_daily.txt \
-v etmg -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn --moving_average 7 \
--ylabel "Etmg (mm/d)" \
--labels "c_rv = 10" "prescribed cover" "prescribed cover - mean monthly"  --title "a)" --legend True  \
--colors red black gray --moving_average 7 --mf 1000\
--figsize 18 4

# %%
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff10.0/sce_best/results_daily.txt \
-v etmt -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn --moving_average 7 \
--ylabel "Etmt (mm/d)" \
--labels "c_rv = 10" "prescribed cover" "prescribed cover - mean monthly"  --title "a)" --legend True  \
--colors red black gray --moving_average 7 --mf 1000\
--figsize 18 4

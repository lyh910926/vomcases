# %% [markdown]
# # States and fluxes VOM

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta, date
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
from scipy.misc import imread
import matplotlib.cbook as cbook

# %% [markdown]
# ## Tree transpiration

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmt -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--ylabel "Tree transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_howard.txt --mf 1000 \
--title "HowardSprings" --legend True

#Litchfield
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/Litchfield/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmt -ys 2015 -ye 2017 -w ../../data/VOM_input/Litchfield/dailyweather.prn \
--ylabel "Tree transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_litch.txt --mf 1000 \
--title "Litchfield" --legend True

#AdelaideRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmt -ys 2007 -ye 2009 -w ../../data/VOM_input/AdelaideRiver/dailyweather.prn \
--ylabel "Tree transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_adelaide.txt --mf 1000 \
--title "AdelaideRiver" --legend True

#DalyUncleared
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmt -ys 2007 -ye 2011 -w ../../data/VOM_input/DalyUncleared/dailyweather.prn \
--ylabel "Tree transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_daly.txt --mf 1000 \
--title "DalyUncleared" --legend True

#DryRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmt -ys 2011 -ye 2015 -w ../../data/VOM_input/DryRiver/dailyweather.prn \
--ylabel "Tree transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_dry.txt --mf 1000 \
--title "DryRiver" --legend True

#SturtPlains
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmt -ys 2009 -ye 2014 -w ../../data/VOM_input/SturtPlains/dailyweather.prn \
--ylabel "Tree transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_sturt.txt --mf 1000 \
--title "SturtPlains" --legend True

# %% [markdown]
# ## Grass transpiration

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmg -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--ylabel "Grass transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_howard.txt --mf 1000 \
--title "HowardSprings" --legend True

#Litchfield
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/Litchfield/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmg -ys 2015 -ye 2017 -w ../../data/VOM_input/Litchfield/dailyweather.prn \
--ylabel "Grass transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_litch.txt --mf 1000 \
--title "Litchfield" --legend True

#AdelaideRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmg -ys 2007 -ye 2009 -w ../../data/VOM_input/AdelaideRiver/dailyweather.prn \
--ylabel "Grass transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_adelaide.txt --mf 1000 \
--title "AdelaideRiver" --legend True

#DalyUncleared
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmg -ys 2007 -ye 2011 -w ../../data/VOM_input/DalyUncleared/dailyweather.prn \
--ylabel "Grass transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_daly.txt --mf 1000 \
--title "DalyUncleared" --legend True

#DryRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmg -ys 2011 -ye 2015 -w ../../data/VOM_input/DryRiver/dailyweather.prn \
--ylabel "Grass transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_dry.txt --mf 1000 \
--title "DryRiver" --legend True

#SturtPlains
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v etmg -ys 2009 -ye 2014 -w ../../data/VOM_input/SturtPlains/dailyweather.prn \
--ylabel "Grass transpiration [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_sturt.txt --mf 1000 \
--title "SturtPlains" --legend True

# %% [markdown]
# ## Soil evaporation

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v esoil -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--ylabel "Soil evaporation [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_howard.txt --mf 1000 \
--title "HowardSprings" --legend True

#Litchfield
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/Litchfield/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v esoil -ys 2015 -ye 2017 -w ../../data/VOM_input/Litchfield/dailyweather.prn \
--ylabel "Soil evaporation [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_litch.txt --mf 1000 \
--title "Litchfield" --legend True

#AdelaideRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v esoil -ys 2007 -ye 2009 -w ../../data/VOM_input/AdelaideRiver/dailyweather.prn \
--ylabel "Soil evaporation [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_adelaide.txt --mf 1000 \
--title "AdelaideRiver" --legend True

#DalyUncleared
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v esoil -ys 2007 -ye 2011 -w ../../data/VOM_input/DalyUncleared/dailyweather.prn \
--ylabel "Soil evaporation [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_daly.txt --mf 1000 \
--title "DalyUncleared" --legend True

#DryRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v esoil -ys 2011 -ye 2015 -w ../../data/VOM_input/DryRiver/dailyweather.prn \
--ylabel "Soil evaporation [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_dry.txt --mf 1000 \
--title "DryRiver" --legend True

#SturtPlains
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v esoil -ys 2009 -ye 2014 -w ../../data/VOM_input/SturtPlains/dailyweather.prn \
--ylabel "Soil evaporation [mm/d]" --labels VOM \
--obs ../../data/DINGO/Ea_sturt.txt --mf 1000 \
--title "SturtPlains" --legend True

# %% [markdown]
# ## Tree assimilation

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--ylabel "Tree ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_howard.txt --mf_obs -1 \
--title "HowardSprings" --legend True

#Litchfield
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/Litchfield/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2015 -ye 2017 -w ../../data/VOM_input/Litchfield/dailyweather.prn \
--ylabel "Tree ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_litch.txt --mf_obs -1 \
--title "Litchfield" --legend True

#AdelaideRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2007 -ye 2009 -w ../../data/VOM_input/AdelaideRiver/dailyweather.prn \
--ylabel "Tree ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_adelaide.txt --mf_obs -1 \
--title "AdelaideRiver" --legend True

#DalyUncleared
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2007 -ye 2011 -w ../../data/VOM_input/DalyUncleared/dailyweather.prn \
--ylabel "Tree ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_daly.txt --mf_obs -1 \
--title "DalyUncleared" --legend True

#DryRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2011 -ye 2015 -w ../../data/VOM_input/DryRiver/dailyweather.prn \
--ylabel "Tree ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_dry.txt --mf_obs -1 \
--title "DryRiver" --legend True

#SturtPlains
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2009 -ye 2014 -w ../../data/VOM_input/SturtPlains/dailyweather.prn \
--ylabel "Tree ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_sturt.txt --mf_obs -1 \
--title "SturtPlains" --legend True

# %% [markdown]
# ## Grass assimilation

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--ylabel "Grass ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_howard.txt --mf_obs -1 \
--title "HowardSprings" --legend True

#Litchfield
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/Litchfield/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2015 -ye 2017 -w ../../data/VOM_input/Litchfield/dailyweather.prn \
--ylabel "Grass ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_litch.txt --mf_obs -1 \
--title "Litchfield" --legend True

#AdelaideRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2007 -ye 2009 -w ../../data/VOM_input/AdelaideRiver/dailyweather.prn \
--ylabel "Grass ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_adelaide.txt --mf_obs -1 \
--title "AdelaideRiver" --legend True

#DalyUncleared
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2007 -ye 2011 -w ../../data/VOM_input/DalyUncleared/dailyweather.prn \
--ylabel "Grass ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_daly.txt --mf_obs -1 \
--title "DalyUncleared" --legend True

#DryRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2011 -ye 2015 -w ../../data/VOM_input/DryRiver/dailyweather.prn \
--ylabel "Grass ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_dry.txt --mf_obs -1 \
--title "DryRiver" --legend True

#SturtPlains
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v asst -ys 2009 -ye 2014 -w ../../data/VOM_input/SturtPlains/dailyweather.prn \
--ylabel "Grass ass.  [mol/m2/d]" --labels VOM \
--obs ../../data/DINGO/GPPdaily_sturt.txt --mf_obs -1 \
--title "SturtPlains" --legend True

# %% [markdown]
# ## Groundwater tables

# %%
#plot groundwater tables, inclusive rooting depths

# %run ../../src_py/plot_gw.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v zw -ys 2011 -ye 2015 \
--ylabel "Water table [m]"  \
--labels VOM \
--colors "blue" \
--i_cz 48.40  \
--pars ../../work/HowardSprings/freedrainage_cpcff1.2/best/input/pars.txt \
--title "HowardSprings" --legend True


# %run ../../src_py/plot_gw.py  \
-i ../../data/VOM_output/Litchfield/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v zw -ys 2011 -ye 2015 \
--ylabel "Water table [m]"  \
--labels VOM \
--colors "blue" \
--i_cz 48.20  \
--pars ../../work/Litchfield/freedrainage_cpcff1.2/best/input/pars.txt \
--title "Litchfield" --legend True

# %run ....//src_py/plot_gw.py  \
-i ../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v zw -ys 2011 -ye 2015 \
--ylabel "Water table [m]"  \
--labels VOM \
--colors "blue" \
--i_cz 8.20  \
--pars ../../work/AdelaideRiver/freedrainage_cpcff1.2/best/input/pars.txt \
--title "AdelaideRiver" --legend True

# %run ../../src_py/plot_gw.py  \
-i ../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v zw -ys 2011 -ye 2015 \
--ylabel "Water table [m]"  \
--labels VOM \
--colors "blue" \
--i_cz 25.0  \
--pars ../../work/DalyUncleared/freedrainage_cpcff1.2/best/input/pars.txt \
--title "DalyUncleared" --legend True

# %run ../../src_py/plot_gw.py  \
-i ../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v zw -ys 2011 -ye 2015 \
--ylabel "Water table [m]"  \
--labels VOM \
--colors "blue" \
--i_cz 20.0  \
--pars ../../work/DryRiver/freedrainage_cpcff1.2/best/input/pars.txt \
--title "DryRiver" --legend True

# %run ../../src_py/plot_gw.py  \
-i ../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v zw -ys 2011 -ye 2015 \
--ylabel "Water table [m]"  \
--labels VOM \
--colors "blue" \
--i_cz 29.0  \
--pars ../../work/SturtPlains/freedrainage_cpcff1.2/best/input/pars.txt \
--title "SturtPlains" --legend True
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Documents/renku-projects/VOM_cases_renku_egu/vomcases/src_py/plot_gw.py in <module>
#     264
#     265
# --> 266 main()
#     267
#     268
#
# ~/Documents/renku-projects/VOM_cases_renku_egu/vomcases/src_py/plot_gw.py in main()
#      95     tmod = []
#      96     for i in range(0, len(args.input)):
# ---> 97         data = np.genfromtxt(args.input[i], names=True)
#      98         if( args.var == "evaptot"):
#      99             vals.append( (data["etmt"] + data["etmg"] + data["esoil"])*args.mf)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
# ...

# %% [markdown]
# ## Soil moisture

# %%
#HowardSprings
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/HowardSprings/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v ws -ys 2011 -ye 2015 -w ../../data/VOM_input/HowardSprings/dailyweather.prn \
--ylabel "Soil moisture [-]" --labels VOM \
--title "HowardSprings"

#AdelaideRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/AdelaideRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v ws -ys 2011 -ye 2015 -w ../../data/VOM_input/AdelaideRiver/dailyweather.prn \
--ylabel "Soil moisture [-]" --labels VOM \
--title "AdelaideRiver"

#Litchfield
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/Litchfield/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v ws -ys 2011 -ye 2015 -w ../../data/VOM_input/Litchfield/dailyweather.prn \
--ylabel "Soil moisture [-]" --labels VOM \
--title "Litchfield"

#DalyUncleared
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DalyUncleared/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v ws -ys 2011 -ye 2015 -w ../../data/VOM_input/DalyUncleared/dailyweather.prn \
--ylabel "Soil moisture [-]" --labels VOM \
--title "DalyUncleared"

#DryRiver
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/DryRiver/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v ws -ys 2011 -ye 2015 -w ../../data/VOM_input/DryRiver/dailyweather.prn \
--ylabel "Soil moisture [-]" --labels VOM \
--title "DryRiver"

#SturtPlains
# %run ../../src_py/plot_et_ass.py  \
-i ../../data/VOM_output/SturtPlains/freedrainage_cpcff1.2/sce_best/results_daily.txt \
-v ws -ys 2011 -ye 2016 -w ../../data/VOM_input/SturtPlains/dailyweather.prn \
--ylabel "Soil moisture [-]" --labels VOM \
--title "SturtPlains"
